# %%
import csv
import pandas as pd

# %%
data = pd.read_csv('/Users/jenny/Desktop/citibike/2013-07-CitiBiketripdata.csv')

# %%
data.head()
# Out:
#    tripduration    starttime     stoptime  start station id  \
# 0           634  7/1/13 0:00  7/1/13 0:10               164
# 1          1547  7/1/13 0:00  7/1/13 0:25               388
# 2           178  7/1/13 0:01  7/1/13 0:04               293
# 3          1580  7/1/13 0:01  7/1/13 0:27               531
# 4           757  7/1/13 0:01  7/1/13 0:13               382
#
#         start station name  start station latitude  start station longitude  \
# 0          E 47 St & 2 Ave               40.753231               -73.970325
# 1         W 26 St & 10 Ave               40.749718               -74.002950
# 2    Lafayette St & E 8 St               40.730287               -73.990765
# 3   Forsyth St & Broome St               40.718939               -73.992663
# 4  University Pl & E 14 St               40.734927               -73.992005
#
#    end station id         end station name  end station latitude  \
# 0             504          1 Ave & E 15 St             40.732219
# ...

# %%
tripduration = data.groupby(['birth year'], as_index=False)['tripduration'].mean()
# tripduration = data.groupby('birth year')['tripduration'].mean()
tripduration.head()
# Out:
#   birth year  tripduration
# 0       1899   1114.952941
# 1       1900   1423.418182
# 2       1901   1105.571429
# 3       1910    710.666667
# 4       1913   1485.461538

# %%
tripduration.to_csv('avgtripduration.csv')

# %%
data2 = pd.read_csv('/Users/jenny/Desktop/citibike/2013-08-CitiBiketripdata.csv')

# %%
data2.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           664  2013-08-01 00:00:00  2013-08-01 00:11:04               449
# 1          2115  2013-08-01 00:00:01  2013-08-01 00:35:16               254
# 2           385  2013-08-01 00:00:03  2013-08-01 00:06:28               460
# 3           653  2013-08-01 00:00:10  2013-08-01 00:11:03               398
# 4           954  2013-08-01 00:00:11  2013-08-01 00:16:05               319
#
#          start station name  start station latitude  start station longitude  \
# 0           W 52 St & 9 Ave               40.764618               -73.987895
# 1           W 11 St & 6 Ave               40.735324               -73.998004
# 2        S 4 St & Wythe Ave               40.712859               -73.965903
# 3  Atlantic Ave & Furman St               40.691652               -73.999979
# 4       Park Pl & Church St               40.713361               -74.009376
#
# ...

# %%
tripduration2 = data2.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration2.head()
# Out:
#   birth year  tripduration
# 0       1899   1258.191489
# 1       1900    992.136986
# 2       1901   1029.013889
# 3       1910   1300.000000
# 4       1913   1528.285714

# %%
tripduration['08-2013'] = tripduration2['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data3 = pd.read_csv('/Users/jenny/Desktop/citibike/2013-09-CitiBiketripdata.csv')

# %%
data3.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          1010  2013-09-01 00:00:02  2013-09-01 00:16:52               254
# 1          1443  2013-09-01 00:00:09  2013-09-01 00:24:12               151
# 2          1387  2013-09-01 00:00:16  2013-09-01 00:23:23               352
# 3           405  2013-09-01 00:00:18  2013-09-01 00:07:03               490
# 4           270  2013-09-01 00:00:20  2013-09-01 00:04:50               236
#
#          start station name  start station latitude  start station longitude  \
# 0           W 11 St & 6 Ave               40.735324               -73.998004
# 1  Cleveland Pl & Spring St               40.721816               -73.997203
# 2           W 56 St & 6 Ave               40.763406               -73.977225
# 3           8 Ave & W 33 St               40.751551               -73.993934
# 4       St Marks Pl & 2 Ave               40.728419               -73.987140
#
# ...

# %%
tripduration3 = data3.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration3.head()
# Out:
#   birth year  tripduration
# 0       1899   1393.531915
# 1       1900    781.371585
# 2       1901    981.424658
# 3       1903    835.000000
# 4       1907   1182.000000

# %%
tripduration['09-2013'] = tripduration3['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data4 = pd.read_csv('/Users/jenny/Desktop/citibike/2013-10-CitiBiketripdata.csv')

# %%
data4.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           326  2013-10-01 00:01:08  2013-10-01 00:06:34               239
# 1           729  2013-10-01 00:01:21  2013-10-01 00:13:30               322
# 2           520  2013-10-01 00:01:24  2013-10-01 00:10:04               174
# 3           281  2013-10-01 00:01:25  2013-10-01 00:06:06               430
# 4           196  2013-10-01 00:01:27  2013-10-01 00:04:43               403
#
#          start station name  start station latitude  start station longitude  \
# 0  Willoughby St & Fleet St               40.691966               -73.981302
# 1   Clinton St & Tillary St               40.696192               -73.991218
# 2           E 25 St & 1 Ave               40.738177               -73.977387
# 3          York St & Jay St               40.701485               -73.986569
# 4            E 2 St & 2 Ave               40.725029               -73.990697
#
# ...

# %%
tripduration4 = data4.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration4.head()
# Out:
#   birth year  tripduration
# 0       1899   1508.258621
# 1       1900    918.262376
# 2       1901   1024.805556
# 3       1907    963.444444
# 4       1910   1323.458333

# %%
tripduration['10-2013'] = tripduration4['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data5 = pd.read_csv('/Users/jenny/Desktop/citibike/2013-11-CitiBiketripdata.csv')

# %%
data5.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           504  2013-11-01 00:00:17  2013-11-01 00:08:41               326
# 1           747  2013-11-01 00:00:20  2013-11-01 00:12:47               375
# 2          1005  2013-11-01 00:00:30  2013-11-01 00:17:15               264
# 3           622  2013-11-01 00:01:29  2013-11-01 00:11:51               472
# 4          1454  2013-11-01 00:01:37  2013-11-01 00:25:51               293
#
#         start station name  start station latitude  start station longitude  \
# 0          E 11 St & 1 Ave               40.729538               -73.984267
# 1  Mercer St & Bleecker St               40.726795               -73.996951
# 2     Maiden Ln & Pearl St               40.707065               -74.007319
# 3       E 32 St & Park Ave               40.745712               -73.981948
# 4    Lafayette St & E 8 St               40.730287               -73.990765
#
# ...

# %%
tripduration5 = data5.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration5.head()
# Out:
#   birth year  tripduration
# 0       1899   1541.864865
# 1       1900    977.541667
# 2       1901    926.894737
# 3       1907    964.444444
# 4       1910   1238.588235

# %%
tripduration['11-2013'] = tripduration5['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data6 = pd.read_csv('/Users/jenny/Desktop/citibike/2013-12-CitiBiketripdata.csv')

# %%
data6.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          1015  2013-12-01 00:00:03  2013-12-01 00:16:58               401
# 1           962  2013-12-01 00:00:07  2013-12-01 00:16:09               312
# 2           768  2013-12-01 00:00:15  2013-12-01 00:13:03               326
# 3           218  2013-12-01 00:00:49  2013-12-01 00:04:27              2021
# 4           550  2013-12-01 00:01:28  2013-12-01 00:10:38               439
#
#         start station name  start station latitude  start station longitude  \
# 0  Allen St & Rivington St               40.720196               -73.989978
# 1  Allen St & E Houston St               40.722055               -73.989111
# 2          E 11 St & 1 Ave               40.729538               -73.984267
# 3          W 45 St & 8 Ave               40.759291               -73.988597
# 4           E 4 St & 2 Ave               40.726281               -73.989780
#
# ...

# %%
tripduration6 = data6.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration6.head()
# Out:
#   birth year  tripduration
# 0       1899   1863.735294
# 1       1900   1027.469136
# 2       1901   1063.636364
# 3       1907    822.000000
# 4       1910   1512.705882

# %%
tripduration['12-2013'] = tripduration6['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data7 = pd.read_csv('/Users/jenny/Desktop/citibike/2014-01-CitiBiketripdata.csv')

# %%
data7.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           471  2014-01-01 00:00:06  2014-01-01 00:07:57              2009
# 1          1494  2014-01-01 00:00:38  2014-01-01 00:25:32               536
# 2           464  2014-01-01 00:03:59  2014-01-01 00:11:43               228
# 3           373  2014-01-01 00:05:15  2014-01-01 00:11:28               519
# 4           660  2014-01-01 00:05:18  2014-01-01 00:16:18                83
#
#               start station name  start station latitude  \
# 0       Catherine St & Monroe St               40.711174
# 1                1 Ave & E 30 St               40.741444
# 2                E 48 St & 3 Ave               40.754601
# 3              Pershing Square N               40.751884
# 4  Atlantic Ave & Fort Greene Pl               40.683826
#
#    start station longitude  end station id          end station name  \
# 0               -73.996826             263  Elizabeth St & Hester St
# ...

# %%
tripduration7 = data7.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration7.head()
# Out:
#   birth year  tripduration
# 0       1899    465.238095
# 1       1900    901.956522
# 2       1901   1200.000000
# 3       1910   1401.750000
# 4       1917   1644.500000

# %%
tripduration['01-2014'] = tripduration7['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data8 = pd.read_csv('/Users/jenny/Desktop/citibike/2014-02-CitiBiketripdata.csv')

# %%
data8.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           382  2014-02-01 00:00:00  2014-02-01 00:06:22               294
# 1           372  2014-02-01 00:00:03  2014-02-01 00:06:15               285
# 2           591  2014-02-01 00:00:09  2014-02-01 00:10:00               247
# 3           583  2014-02-01 00:00:32  2014-02-01 00:10:15               357
# 4           223  2014-02-01 00:00:41  2014-02-01 00:04:24               401
#
#         start station name  start station latitude  start station longitude  \
# 0      Washington Square E               40.730494               -73.995721
# 1       Broadway & E 14 St               40.734546               -73.990741
# 2   Perry St & Bleecker St               40.735354               -74.004831
# 3       E 11 St & Broadway               40.732618               -73.991580
# 4  Allen St & Rivington St               40.720196               -73.989978
#
# ...

# %%
tripduration8 = data8.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration8.head()
# Out:
#   birth year  tripduration
# 0       1899    719.444444
# 1       1900    982.029412
# 2       1901   1330.636364
# 3       1907    574.800000
# 4       1910   1613.250000

# %%
tripduration['02-2014'] = tripduration8['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data9 = pd.read_csv('/Users/jenny/Desktop/citibike/2014-03-CitiBiketripdata.csv')

# %%
data9.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           949  2014-03-01 00:00:16  2014-03-01 00:16:05               317
# 1           533  2014-03-01 00:00:57  2014-03-01 00:09:50               457
# 2           122  2014-03-01 00:01:06  2014-03-01 00:03:08               146
# 3           134  2014-03-01 00:01:14  2014-03-01 00:03:28               146
# 4           997  2014-03-01 00:01:18  2014-03-01 00:17:55               150
#
#      start station name  start station latitude  start station longitude  \
# 0     E 6 St & Avenue B               40.724537               -73.981854
# 1    Broadway & W 58 St               40.766953               -73.981693
# 2  Hudson St & Reade St               40.716250               -74.009106
# 3  Hudson St & Reade St               40.716250               -74.009106
# 4     E 2 St & Avenue C               40.720874               -73.980858
#
#    end station id         end station name  end station latitude  \
# ...

# %%
tripduration9 = data9.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration9.head()
# Out:
#   birth year  tripduration
# 0       1899   1026.428571
# 1       1900   1073.978723
# 2       1901    652.387097
# 3       1910   1477.125000
# 4       1913   1026.000000

# %%
tripduration['03-2014'] = tripduration9['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data10 = pd.read_csv('/Users/jenny/Desktop/citibike/2014-04-CitiBiketripdata.csv')

# %%
data10.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           558  2014-04-01 00:00:07  2014-04-01 00:09:25                82
# 1           882  2014-04-01 00:00:20  2014-04-01 00:15:02               349
# 2           587  2014-04-01 00:00:25  2014-04-01 00:10:12               293
# 3           355  2014-04-01 00:00:44  2014-04-01 00:06:39               539
# 4           524  2014-04-01 00:01:29  2014-04-01 00:10:13               459
#
#                start station name  start station latitude  \
# 0          St James Pl & Pearl St               40.711174
# 1         Rivington St & Ridge St               40.718502
# 2           Lafayette St & E 8 St               40.730287
# 3  Metropolitan Ave & Bedford Ave               40.715348
# 4                W 20 St & 11 Ave               40.746745
#
#    start station longitude  end station id         end station name  \
# 0               -74.000165            2008    Little West St & 1 Pl
# ...

# %%
tripduration10 = data10.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration10.head()
# Out:
#   birth year  tripduration
# 0       1899    676.526316
# 1       1900   1061.472906
# 2       1901    663.937500
# 3       1907   1053.666667
# 4       1910    659.714286

# %%
tripduration['04-2014'] = tripduration10['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data11 = pd.read_csv('/Users/jenny/Desktop/citibike/2014-05-CitiBiketripdata.csv')

# %%
data11.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           158  2014-05-01 00:08:32  2014-05-01 00:11:10               438
# 1           427  2014-05-01 00:10:16  2014-05-01 00:17:23               537
# 2           357  2014-05-01 00:12:28  2014-05-01 00:18:25               491
# 3           168  2014-05-01 00:13:41  2014-05-01 00:16:29               224
# 4           638  2014-05-01 00:15:45  2014-05-01 00:26:23               454
#
#         start station name  start station latitude  start station longitude  \
# 0      St Marks Pl & 1 Ave               40.727791               -73.985649
# 1  Lexington Ave & E 24 St               40.740259               -73.984092
# 2     E 24 St & Park Ave S               40.740964               -73.986022
# 3    Spruce St & Nassau St               40.711464               -74.005524
# 4          E 51 St & 1 Ave               40.754557               -73.965930
#
# ...

# %%
tripduration11 = data11.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration11.head()
# Out:
#   birth year  tripduration
# 0       1899    873.078431
# 1       1900   1019.674897
# 2       1901    623.369863
# 3       1907    691.500000
# 4       1910   1187.119048

# %%
tripduration['05-2014'] = tripduration11['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data12 = pd.read_csv('/Users/jenny/Desktop/citibike/2014-06-CitiBiketripdata.csv')

# %%
data12.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           520  2014-06-01 00:00:02  2014-06-01 00:08:42               358
# 1           520  2014-06-01 00:00:27  2014-06-01 00:09:07               335
# 2           414  2014-06-01 00:00:32  2014-06-01 00:07:26               439
# 3           310  2014-06-01 00:00:34  2014-06-01 00:05:44               463
# 4           457  2014-06-01 00:00:35  2014-06-01 00:08:12               352
#
#               start station name  start station latitude  \
# 0  Christopher St & Greenwich St               40.732916
# 1       Washington Pl & Broadway               40.729039
# 2                 E 4 St & 2 Ave               40.726281
# 3                9 Ave & W 16 St               40.742065
# 4                W 56 St & 6 Ave               40.763406
#
#    start station longitude  end station id          end station name  \
# 0               -74.007114             426     West St & Chambers St
# ...

# %%
tripduration12 = data12.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration12.head()
# Out:
#   birth year  tripduration
# 0       1899    956.857143
# 1       1900    933.353571
# 2       1901    734.257576
# 3       1907    556.666667
# 4       1910   1064.961538

# %%
tripduration['06-2014'] = tripduration12['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data13 = pd.read_csv('/Users/jenny/Desktop/citibike/2014-07-CitiBiketripdata.csv')

# %%
data13.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           404  2014-07-01 00:00:04  2014-07-01 00:06:48               545
# 1           850  2014-07-01 00:00:06  2014-07-01 00:14:16               238
# 2          1550  2014-07-01 00:00:21  2014-07-01 00:26:11               223
# 3           397  2014-07-01 00:00:29  2014-07-01 00:07:06               224
# 4           609  2014-07-01 00:00:37  2014-07-01 00:10:46               346
#
#         start station name  start station latitude  start station longitude  \
# 0          E 23 St & 1 Ave               40.736502               -73.978095
# 1  Bank St & Washington St               40.736197               -74.008592
# 2          W 13 St & 7 Ave               40.737815               -73.999947
# 3    Spruce St & Nassau St               40.711464               -74.005524
# 4      Bank St & Hudson St               40.736529               -74.006180
#
# ...

# %%
tripduration13 = data13.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration13.head()
# Out:
#   birth year  tripduration
# 0       1899   1261.432432
# 1       1900   1058.966346
# 2       1901    729.500000
# 3       1907   1130.500000
# 4       1910   1645.363636

# %%
tripduration['07-2014'] = tripduration13['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data14 = pd.read_csv('/Users/jenny/Desktop/citibike/2014-08-CitiBiketripdata.csv')

# %%
data14.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          1142  2014-08-01 00:00:04  2014-08-01 00:19:06               470
# 1           117  2014-08-01 00:00:05  2014-08-01 00:02:02               236
# 2           546  2014-08-01 00:00:07  2014-08-01 00:09:13               224
# 3          2126  2014-08-01 00:00:11  2014-08-01 00:35:37               150
# 4           329  2014-08-01 00:00:15  2014-08-01 00:05:44               519
#
#          start station name  start station latitude  start station longitude  \
# 0           W 20 St & 8 Ave               40.743453               -74.000040
# 1       St Marks Pl & 2 Ave               40.728419               -73.987140
# 2     Spruce St & Nassau St               40.711464               -74.005524
# 3         E 2 St & Avenue C               40.720874               -73.980858
# 4  E 42 St & Vanderbilt Ave               40.752416               -73.978370
#
# ...

# %%
tripduration14 = data14.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration14.head()
# Out:
#   birth year  tripduration
# 0       1899   1288.051724
# 1       1900    905.804444
# 2       1901    705.409091
# 3       1907    859.000000
# 4       1910   1245.375000

# %%
tripduration['08-2014'] = tripduration14['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data15 = pd.read_csv('/Users/jenny/Desktop/citibike/201409-citibike-tripdata.csv')

# %%
data15.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0          2828  9/1/2014 00:00:25  9/1/2014 00:47:33               386
# 1           368  9/1/2014 00:00:28  9/1/2014 00:06:36               387
# 2          2201  9/1/2014 00:00:40  9/1/2014 00:37:21               386
# 3           322  9/1/2014 00:00:41  9/1/2014 00:06:03               167
# 4          1693  9/1/2014 00:00:59  9/1/2014 00:29:12               223
#
#         start station name  start station latitude  start station longitude  \
# 0     Centre St & Worth St               40.714948               -74.002345
# 1  Centre St & Chambers St               40.712733               -74.004607
# 2     Centre St & Worth St               40.714948               -74.002345
# 3          E 39 St & 3 Ave               40.748901               -73.976049
# 4          W 13 St & 7 Ave               40.737815               -73.999947
#
#    end station id               end station name  end station latitude  \
# ...

# %%
tripduration15 = data15.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration15.head()
# Out:
#    birth year  tripduration
# 0      1899.0   1358.439024
# 1      1900.0   1016.034826
# 2      1901.0    722.292308
# 3      1907.0    510.666667
# 4      1910.0   1474.875000

# %%
tripduration['09-2014'] = tripduration15['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data16 = pd.read_csv('/Users/jenny/Desktop/citibike/201410-citibike-tripdata.csv')

# %%
data16.head()
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 0          1027  10/1/2014 00:00:27  10/1/2014 00:17:34               479
# 1           534  10/1/2014 00:00:36  10/1/2014 00:09:30               417
# 2           416  10/1/2014 00:00:42  10/1/2014 00:07:38               327
# 3           428  10/1/2014 00:00:50  10/1/2014 00:07:58               515
# 4           281  10/1/2014 00:01:08  10/1/2014 00:05:49               497
#
#          start station name  start station latitude  start station longitude  \
# 0           9 Ave & W 45 St               40.760193               -73.991255
# 1    Barclay St & Church St               40.712912               -74.010202
# 2  Vesey Pl & River Terrace               40.715338               -74.016584
# 3          W 43 St & 10 Ave               40.760094               -73.994618
# 4        E 17 St & Broadway               40.737050               -73.990093
#
# ...

# %%
tripduration16 = data16.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration16.head()
# Out:
#    birth year  tripduration
# 0      1899.0   1130.526316
# 1      1900.0    896.202312
# 2      1901.0    783.541667
# 3      1907.0    569.727273
# 4      1910.0   1464.600000

# %%
tripduration['10-2014'] = tripduration16['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data17 = pd.read_csv('/Users/jenny/Desktop/citibike/201411-citibike-tripdata.csv')

# %%
data17.head()
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 0            97  11/1/2014 00:00:11  11/1/2014 00:01:48               344
# 1           604  11/1/2014 00:00:11  11/1/2014 00:10:15               477
# 2           629  11/1/2014 00:00:38  11/1/2014 00:11:07               546
# 3           939  11/1/2014 00:00:49  11/1/2014 00:16:28               284
# 4           825  11/1/2014 00:00:56  11/1/2014 00:14:41               280
#
#         start station name  start station latitude  start station longitude  \
# 0  Monroe St & Bedford Ave               40.685144               -73.953809
# 1          W 41 St & 8 Ave               40.756405               -73.990026
# 2     E 30 St & Park Ave S               40.744449               -73.983035
# 3    Greenwich Ave & 8 Ave               40.739017               -74.002638
# 4          E 10 St & 5 Ave               40.733320               -73.995101
#
# ...

# %%
tripduration17 = data17.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration17.head()
# Out:
#    birth year  tripduration
# 0      1899.0   1204.000000
# 1      1900.0    969.762712
# 2      1901.0    805.877551
# 3      1907.0    703.333333
# 4      1910.0   1719.000000

# %%
tripduration['11-2014'] = tripduration17['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data18 = pd.read_csv('/Users/jenny/Desktop/citibike/201412-citibike-tripdata.csv')

# %%
data18.head()
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 0          1257  12/1/2014 00:00:28  12/1/2014 00:21:25               475
# 1           275  12/1/2014 00:00:43  12/1/2014 00:05:18               498
# 2           450  12/1/2014 00:01:22  12/1/2014 00:08:52               444
# 3          1126  12/1/2014 00:02:17  12/1/2014 00:21:03               475
# 4           331  12/1/2014 00:02:21  12/1/2014 00:07:52               519
#
#       start station name  start station latitude  start station longitude  \
# 0    E 16 St & Irving Pl               40.735243               -73.987586
# 1     Broadway & W 32 St               40.748549               -73.988084
# 2     Broadway & W 24 St               40.742354               -73.989151
# 3    E 16 St & Irving Pl               40.735243               -73.987586
# 4  Pershing Square North               40.751873               -73.977706
#
#    end station id      end station name  end station latitude  \
# ...

# %%
tripduration18 = data18.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration18.head()
# Out:
#    birth year  tripduration
# 0      1899.0    714.600000
# 1      1900.0    939.495652
# 2      1901.0    618.733333
# 3      1910.0   1529.500000
# 4      1921.0    354.166667

# %%
tripduration['12-2014'] = tripduration18['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data19 = pd.read_csv('/Users/jenny/Desktop/citibike/201501-citibike-tripdata.csv')

# %%
data19.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0          1346  1/1/2015 0:01  1/1/2015 0:24               455
# 1           363  1/1/2015 0:02  1/1/2015 0:08               434
# 2           346  1/1/2015 0:04  1/1/2015 0:10               491
# 3           182  1/1/2015 0:04  1/1/2015 0:07               384
# 4           969  1/1/2015 0:05  1/1/2015 0:21               474
#
#         start station name  start station latitude  start station longitude  \
# 0          1 Ave & E 44 St               40.750020               -73.969053
# 1          9 Ave & W 18 St               40.743174               -74.003664
# 2     E 24 St & Park Ave S               40.740964               -73.986022
# 3  Fulton St & Waverly Ave               40.683178               -73.965964
# 4          5 Ave & E 29 St               40.745168               -73.986831
#
#    end station id             end station name  end station latitude  \
# ...

# %%
tripduration19 = data19.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration19.head()
# Out:
#    birth year  tripduration
# 0      1899.0   1143.333333
# 1      1900.0   1111.707865
# 2      1901.0   1052.000000
# 3      1910.0   1430.000000
# 4      1922.0    425.882353

# %%
tripduration['01-2015'] = tripduration19['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data20 = pd.read_csv('/Users/jenny/Desktop/citibike/201502-citibike-tripdata.csv')

# %%
data20.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0           801  2/1/2015 0:00  2/1/2015 0:14               521
# 1           379  2/1/2015 0:00  2/1/2015 0:07               497
# 2          2474  2/1/2015 0:01  2/1/2015 0:42               281
# 3           818  2/1/2015 0:01  2/1/2015 0:15              2004
# 4           544  2/1/2015 0:01  2/1/2015 0:10               323
#
#                   start station name  start station latitude  \
# 0                    8 Ave & W 31 St               40.750450
# 1                 E 17 St & Broadway               40.737050
# 2  Grand Army Plaza & Central Park S               40.764397
# 3                  6 Ave & Broome St               40.724399
# 4        Lawrence St & Willoughby St               40.692362
#
#    start station longitude  end station id               end station name  \
# 0               -73.994811             423                W 54 St & 9 Ave
# ...

# %%
tripduration20 = data20.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration20.head()
# Out:
#    birth year  tripduration
# 0      1899.0   1547.500000
# 1      1900.0   1099.216867
# 2      1901.0   1217.444444
# 3      1910.0   1659.000000
# 4      1922.0    478.416667

# %%
tripduration['02-2015'] = tripduration20['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data21 = pd.read_csv('/Users/jenny/Desktop/citibike/201503-citibike-tripdata.csv')

# %%
data21.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0           669  3/1/2015 0:00  3/1/2015 0:11               164
# 1           750  3/1/2015 0:01  3/1/2015 0:14               258
# 2           663  3/1/2015 0:01  3/1/2015 0:12               497
# 3           480  3/1/2015 0:02  3/1/2015 0:10               470
# 4          1258  3/1/2015 0:02  3/1/2015 0:23               345
#
#             start station name  start station latitude  \
# 0              E 47 St & 2 Ave               40.753231
# 1  DeKalb Ave & Vanderbilt Ave               40.689407
# 2           E 17 St & Broadway               40.737050
# 3              W 20 St & 8 Ave               40.743453
# 4              W 13 St & 6 Ave               40.736494
#
#    start station longitude  end station id            end station name  \
# 0               -73.970325             477             W 41 St & 8 Ave
# 1               -73.968855             436    Hancock St & Bedford Ave
# ...

# %%
tripduration21 = data21.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration21.head()
# Out:
#    birth year  tripduration
# 0      1899.0   1079.769231
# 1      1900.0   1049.294118
# 2      1901.0   1160.700000
# 3      1907.0    831.000000
# 4      1910.0   1215.666667

# %%
tripduration['03-2015'] = tripduration21['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data22 = pd.read_csv('/Users/jenny/Desktop/citibike/201504-citibike-tripdata.csv')

# %%
data22.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           241  4/1/2015 00:00:23  4/1/2015 00:04:25               494
# 1           578  4/1/2015 00:00:52  4/1/2015 00:10:31                82
# 2           484  4/1/2015 00:01:28  4/1/2015 00:09:33               223
# 3          1144  4/1/2015 00:01:31  4/1/2015 00:20:36               393
# 4          1023  4/1/2015 00:01:36  4/1/2015 00:18:40               212
#
#         start station name  start station latitude  start station longitude  \
# 0          W 26 St & 8 Ave               40.747348               -73.997236
# 1   St James Pl & Pearl St               40.711174               -74.000165
# 2          W 13 St & 7 Ave               40.737815               -73.999947
# 3        E 5 St & Avenue C               40.722992               -73.979955
# 4  W 16 St & The High Line               40.743349               -74.006818
#
#    end station id       end station name  end station latitude  \
# ...

# %%
tripduration22 = data22.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration22.head()
# Out:
#    birth year  tripduration
# 0      1885.0   1086.578947
# 1      1899.0   1212.673469
# 2      1900.0   1087.213793
# 3      1901.0    884.222222
# 4      1910.0   1653.000000

# %%
tripduration['04-2015'] = tripduration22['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data23 = pd.read_csv('/Users/jenny/Desktop/citibike/201505-citibike-tripdata.csv')

# %%
data23.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           415  5/1/2015 00:00:11  5/1/2015 00:07:06               477
# 1          1523  5/1/2015 00:00:28  5/1/2015 00:25:52               293
# 2           642  5/1/2015 00:00:52  5/1/2015 00:11:35               380
# 3           367  5/1/2015 00:00:48  5/1/2015 00:06:55               537
# 4          2734  5/1/2015 00:00:51  5/1/2015 00:46:26               426
#
#         start station name  start station latitude  start station longitude  \
# 0          W 41 St & 8 Ave               40.756405               -73.990026
# 1    Lafayette St & E 8 St               40.730287               -73.990765
# 2         W 4 St & 7 Ave S               40.734011               -74.002939
# 3  Lexington Ave & E 24 St               40.740259               -73.984092
# 4    West St & Chambers St               40.717548               -74.013221
#
#    end station id          end station name  end station latitude  \
# ...

# %%
tripduration23 = data23.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration23.head()
# Out:
#    birth year  tripduration
# 0      1885.0    969.156250
# 1      1899.0   1260.458333
# 2      1900.0   1119.164557
# 3      1901.0   1015.379310
# 4      1917.0    655.000000

# %%
tripduration['05-2015'] = tripduration23['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data24 = pd.read_csv('/Users/jenny/Desktop/citibike/201506-citibike-tripdata.csv')

# %%
data24.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0          1338  6/1/2015 0:00  6/1/2015 0:22               128
# 1           290  6/1/2015 0:00  6/1/2015 0:05               438
# 2           634  6/1/2015 0:01  6/1/2015 0:11               383
# 3           159  6/1/2015 0:01  6/1/2015 0:04               361
# 4          1233  6/1/2015 0:02  6/1/2015 0:22               382
#
#            start station name  start station latitude  \
# 0    MacDougal St & Prince St               40.727103
# 1         St Marks Pl & 1 Ave               40.727791
# 2  Greenwich Ave & Charles St               40.735238
# 3        Allen St & Hester St               40.716059
# 4     University Pl & E 14 St               40.734927
#
#    start station longitude  end station id         end station name  \
# 0               -74.002971            2021          W 45 St & 8 Ave
# 1               -73.985649             312  Allen St & E Houston St
# ...

# %%
tripduration24 = data24.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration24.head()
# Out:
#    birth year  tripduration
# 0      1885.0   1029.959184
# 1      1899.0   1201.833333
# 2      1900.0   1182.626866
# 3      1901.0   1825.689655
# 4      1907.0    796.600000

# %%
tripduration['06-2015'] = tripduration24['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data25 = pd.read_csv('/Users/jenny/Desktop/citibike/201507-citibike-tripdata.csv')

# %%
data25.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           732  7/1/2015 00:00:03  7/1/2015 00:12:16               489
# 1           322  7/1/2015 00:00:06  7/1/2015 00:05:29               304
# 2           790  7/1/2015 00:00:17  7/1/2015 00:13:28               447
# 3          1228  7/1/2015 00:00:23  7/1/2015 00:20:51               490
# 4          1383  7/1/2015 00:00:44  7/1/2015 00:23:48               327
#
#          start station name  start station latitude  start station longitude  \
# 0          10 Ave & W 28 St               40.750664               -74.001768
# 1     Broadway & Battery Pl               40.704633               -74.013617
# 2           8 Ave & W 52 St               40.763707               -73.985162
# 3           8 Ave & W 33 St               40.751551               -73.993934
# 4  Vesey Pl & River Terrace               40.715338               -74.016584
#
# ...

# %%
tripduration25 = data25.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration25.head()
# Out:
#    birth year  tripduration
# 0      1885.0   1133.404255
# 1      1899.0    996.512195
# 2      1900.0   1166.728814
# 3      1901.0    934.800000
# 4      1907.0    956.000000

# %%
tripduration['07-2015'] = tripduration25['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data26 = pd.read_csv('/Users/jenny/Desktop/citibike/201508-citibike-tripdata.csv')

# %%
data26.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0          1202  8/1/2015 00:00:04  8/1/2015 00:20:07               168
# 1           301  8/1/2015 00:00:05  8/1/2015 00:05:06               450
# 2           431  8/1/2015 00:00:06  8/1/2015 00:07:18               312
# 3           273  8/1/2015 00:00:09  8/1/2015 00:04:43               382
# 4          1256  8/1/2015 00:00:17  8/1/2015 00:21:13               352
#
#         start station name  start station latitude  start station longitude  \
# 0          W 18 St & 6 Ave               40.739713               -73.994564
# 1          W 49 St & 8 Ave               40.762272               -73.987882
# 2  Allen St & E Houston St               40.722055               -73.989111
# 3  University Pl & E 14 St               40.734927               -73.992005
# 4          W 56 St & 6 Ave               40.763406               -73.977225
#
#    end station id      end station name  end station latitude  \
# ...

# %%
tripduration26 = data26.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration26.head()
# Out:
#    birth year  tripduration
# 0      1885.0    889.220000
# 1      1899.0    978.666667
# 2      1900.0   1231.142857
# 3      1901.0    875.590909
# 4      1907.0    610.400000

# %%
tripduration['08-2015'] = tripduration26['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data27 = pd.read_csv('/Users/jenny/Desktop/citibike/201509-citibike-tripdata.csv')

# %%
data27.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           288  9/1/2015 00:00:00  9/1/2015 00:04:48               263
# 1           165  9/1/2015 00:00:00  9/1/2015 00:02:45               495
# 2           367  9/1/2015 00:00:01  9/1/2015 00:06:08              3119
# 3           926  9/1/2015 00:00:07  9/1/2015 00:15:34               536
# 4           658  9/1/2015 00:00:09  9/1/2015 00:11:07               347
#
#             start station name  start station latitude  \
# 0     Elizabeth St & Hester St               40.717290
# 1             W 47 St & 10 Ave               40.762699
# 2         Vernon Blvd & 50 Ave               40.742327
# 3              1 Ave & E 30 St               40.741444
# 4  Greenwich St & W Houston St               40.728846
#
#    start station longitude  end station id            end station name  \
# 0               -73.996375             307       Canal St & Rutgers St
# ...

# %%
tripduration27 = data27.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration27.head()
# Out:
#    birth year  tripduration
# 0      1885.0    821.276596
# 1      1896.0    874.857143
# 2      1899.0   1726.615385
# 3      1900.0   1068.976608
# 4      1901.0    921.384615

# %%
tripduration['09-2015'] = tripduration27['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data28 = pd.read_csv('/Users/jenny/Desktop/citibike/201510-citibike-tripdata.csv')

# %%
data28.head()
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 0           171  10/1/2015 00:00:02  10/1/2015 00:02:54               388
# 1           593  10/1/2015 00:00:02  10/1/2015 00:09:55               518
# 2           233  10/1/2015 00:00:11  10/1/2015 00:04:05               447
# 3           250  10/1/2015 00:00:15  10/1/2015 00:04:25               336
# 4           528  10/1/2015 00:00:17  10/1/2015 00:09:05              3107
#
#             start station name  start station latitude  \
# 0             W 26 St & 10 Ave               40.749718
# 1              E 39 St & 2 Ave               40.747804
# 2              8 Ave & W 52 St               40.763707
# 3  Sullivan St & Washington Sq               40.730477
# 4     Bedford Ave & Nassau Ave               40.723117
#
#    start station longitude  end station id                end station name  \
# 0               -74.002950             494                 W 26 St & 8 Ave
# ...

# %%
tripduration28 = data28.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration28.head()
# Out:
#    birth year  tripduration
# 0      1885.0    982.873786
# 1      1896.0   1215.142857
# 2      1899.0    870.277778
# 3      1900.0   1048.005917
# 4      1901.0    887.222222

# %%
tripduration['10-2015'] = tripduration28['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data29 = pd.read_csv('/Users/jenny/Desktop/citibike/201511-citibike-tripdata.csv')

# %%
data29.head()
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 0          1110  11/1/2015 00:00:00  11/1/2015 00:18:31               537
# 1          1094  11/1/2015 00:00:01  11/1/2015 00:18:15               537
# 2           520  11/1/2015 00:00:05  11/1/2015 00:08:45               536
# 3           753  11/1/2015 00:00:15  11/1/2015 00:12:48               229
# 4           353  11/1/2015 00:00:22  11/1/2015 00:06:15               285
#
#         start station name  start station latitude  start station longitude  \
# 0  Lexington Ave & E 24 St               40.740259               -73.984092
# 1  Lexington Ave & E 24 St               40.740259               -73.984092
# 2          1 Ave & E 30 St               40.741444               -73.975361
# 3           Great Jones St               40.727434               -73.993790
# 4       Broadway & E 14 St               40.734546               -73.990741
#
# ...

# %%
tripduration29 = data29.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration29.head()
# Out:
#    birth year  tripduration
# 0      1885.0    717.579545
# 1      1899.0   1169.923077
# 2      1900.0   1335.642857
# 3      1901.0    872.400000
# 4      1907.0    682.500000

# %%
tripduration['11-2015'] = tripduration29['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data30 = pd.read_csv('/Users/jenny/Desktop/citibike/201512-citibike-tripdata.csv')

# %%
data30.head()
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 0           475  12/1/2015 07:35:36  12/1/2015 07:43:32                72
# 1           684  12/1/2015 07:38:15  12/1/2015 07:49:39                72
# 2          1063  12/1/2015 07:44:49  12/1/2015 08:02:33                72
# 3          1075  12/1/2015 08:02:29  12/1/2015 08:20:24                72
# 4           293  12/1/2015 08:06:37  12/1/2015 08:11:30                72
#
#   start station name  start station latitude  start station longitude  \
# 0   W 52 St & 11 Ave               40.767272               -73.993929
# 1   W 52 St & 11 Ave               40.767272               -73.993929
# 2   W 52 St & 11 Ave               40.767272               -73.993929
# 3   W 52 St & 11 Ave               40.767272               -73.993929
# 4   W 52 St & 11 Ave               40.767272               -73.993929
#
#    end station id               end station name  end station latitude  \
# ...

# %%
tripduration30 = data30.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration30.head()
# Out:
#    birth year  tripduration
# 0      1885.0    776.793651
# 1      1899.0   1669.888889
# 2      1900.0   1000.060870
# 3      1901.0    985.900000
# 4      1907.0   6607.000000

# %%
tripduration['12-2015'] = tripduration30['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data31 = pd.read_csv('/Users/jenny/Desktop/citibike/201601-citibike-tripdata.csv')

# %%
data31.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           923  1/1/2016 00:00:41  1/1/2016 00:16:04               268
# 1           379  1/1/2016 00:00:45  1/1/2016 00:07:04               476
# 2           589  1/1/2016 00:00:48  1/1/2016 00:10:37               489
# 3           889  1/1/2016 00:01:06  1/1/2016 00:15:56               268
# 4          1480  1/1/2016 00:01:12  1/1/2016 00:25:52              2006
#
#        start station name  start station latitude  start station longitude  \
# 0   Howard St & Centre St               40.719105               -73.999733
# 1         E 31 St & 3 Ave               40.743943               -73.979661
# 2        10 Ave & W 28 St               40.750664               -74.001768
# 3   Howard St & Centre St               40.719105               -73.999733
# 4  Central Park S & 6 Ave               40.765909               -73.976342
#
#    end station id            end station name  end station latitude  \
# ...

# %%
tripduration31 = data31.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration31.head()
# Out:
#    birth year  tripduration
# 0      1885.0    803.365079
# 1      1899.0   1130.125000
# 2      1900.0   1088.458333
# 3      1901.0   1227.388889
# 4      1907.0   1279.000000

# %%
tripduration['01-2016'] = tripduration31['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data32 = pd.read_csv('/Users/jenny/Desktop/citibike/201602-citibike-tripdata.csv')

# %%
data32.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           461  2/1/2016 00:00:08  2/1/2016 00:07:49               480
# 1           297  2/1/2016 00:00:56  2/1/2016 00:05:53               463
# 2           280  2/1/2016 00:01:00  2/1/2016 00:05:40              3134
# 3           662  2/1/2016 00:01:00  2/1/2016 00:12:02               537
# 4           355  2/1/2016 00:01:41  2/1/2016 00:07:36               284
#
#         start station name  start station latitude  start station longitude  \
# 0         W 53 St & 10 Ave               40.766697               -73.990617
# 1          9 Ave & W 16 St               40.742065               -74.004432
# 2          3 Ave & E 62 St               40.763126               -73.965269
# 3  Lexington Ave & E 24 St               40.740259               -73.984092
# 4    Greenwich Ave & 8 Ave               40.739017               -74.002638
#
#    end station id  end station name  end station latitude  \
# ...

# %%
tripduration32 = data32.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration32.head()
# Out:
#    birth year  tripduration
# 0      1885.0    814.436170
# 1      1899.0   1077.894737
# 2      1900.0    784.069307
# 3      1901.0   1538.500000
# 4      1907.0   1042.000000

# %%
tripduration['02-2016'] = tripduration32['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data33 = pd.read_csv('/Users/jenny/Desktop/citibike/201603-citibike-tripdata.csv')

# %%
data33.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0          1491  3/1/2016 06:52:42  3/1/2016 07:17:33                72
# 1          1044  3/1/2016 07:05:50  3/1/2016 07:23:15                72
# 2           714  3/1/2016 07:15:05  3/1/2016 07:26:59                72
# 3           329  3/1/2016 07:26:04  3/1/2016 07:31:34                72
# 4          1871  3/1/2016 07:31:30  3/1/2016 08:02:41                72
#
#   start station name  start station latitude  start station longitude  \
# 0   W 52 St & 11 Ave               40.767272               -73.993929
# 1   W 52 St & 11 Ave               40.767272               -73.993929
# 2   W 52 St & 11 Ave               40.767272               -73.993929
# 3   W 52 St & 11 Ave               40.767272               -73.993929
# 4   W 52 St & 11 Ave               40.767272               -73.993929
#
#    end station id          end station name  end station latitude  \
# ...

# %%
tripduration33 = data33.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration33.head()
# Out:
#    birth year  tripduration
# 0      1885.0   2403.038835
# 1      1899.0   1109.205882
# 2      1900.0    874.561983
# 3      1901.0   1088.176471
# 4      1907.0   1020.500000

# %%
tripduration['03-2016'] = tripduration33['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data34 = pd.read_csv('/Users/jenny/Desktop/citibike/201604-citibike-tripdata.csv')

# %%
data34.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           496  4/1/2016 00:00:26  4/1/2016 00:08:42               254
# 1           104  4/1/2016 00:00:27  4/1/2016 00:02:12               311
# 2           128  4/1/2016 00:00:30  4/1/2016 00:02:38              3064
# 3          1197  4/1/2016 00:00:34  4/1/2016 00:20:31              3156
# 4           419  4/1/2016 00:00:46  4/1/2016 00:07:46               116
#
#        start station name  start station latitude  start station longitude  \
# 0         W 11 St & 6 Ave               40.735324               -73.998004
# 1  Norfolk St & Broome St               40.717227               -73.988021
# 2  Myrtle Ave & Lewis Ave               40.696820               -73.937569
# 3      E 72 St & York Ave               40.766638               -73.953483
# 4         W 17 St & 8 Ave               40.741776               -74.001497
#
#    end station id                 end station name  end station latitude  \
# ...

# %%
tripduration34 = data34.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration34.head()
# Out:
#    birth year  tripduration
# 0      1885.0    822.455882
# 1      1894.0   5754.333333
# 2      1899.0    978.878788
# 3      1900.0    949.798165
# 4      1901.0   1074.482759

# %%
tripduration['04-2016'] = tripduration34['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data35 = pd.read_csv('/Users/jenny/Desktop/citibike/201605-citibike-tripdata.csv')

# %%
data35.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           538  5/1/2016 00:00:03  5/1/2016 00:09:02               536
# 1           224  5/1/2016 00:00:04  5/1/2016 00:03:49               361
# 2           328  5/1/2016 00:00:14  5/1/2016 00:05:43               301
# 3          1196  5/1/2016 00:00:20  5/1/2016 00:20:17              3141
# 4           753  5/1/2016 00:00:26  5/1/2016 00:13:00               492
#
#      start station name  start station latitude  start station longitude  \
# 0       1 Ave & E 30 St               40.741444               -73.975361
# 1  Allen St & Hester St               40.716059               -73.991908
# 2     E 2 St & Avenue B               40.722174               -73.983688
# 3       1 Ave & E 68 St               40.765005               -73.958185
# 4       W 33 St & 7 Ave               40.750200               -73.990931
#
#    end station id         end station name  end station latitude  \
# ...

# %%
tripduration35 = data35.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration35.head()
# Out:
#    birth year  tripduration
# 0      1885.0    779.555556
# 1      1888.0   1067.400000
# 2      1894.0    359.142857
# 3      1899.0   1175.333333
# 4      1900.0   1057.813953

# %%
tripduration['05-2016'] = tripduration35['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data36 = pd.read_csv('/Users/jenny/Desktop/citibike/201606-citibike-tripdata.csv')

# %%
data36.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0          1470  6/1/2016 00:00:18  6/1/2016 00:24:48               380
# 1           229  6/1/2016 00:00:20  6/1/2016 00:04:09              3092
# 2           344  6/1/2016 00:00:21  6/1/2016 00:06:06               449
# 3          1120  6/1/2016 00:00:28  6/1/2016 00:19:09               522
# 4           229  6/1/2016 00:00:53  6/1/2016 00:04:42               335
#
#          start station name  start station latitude  start station longitude  \
# 0          W 4 St & 7 Ave S               40.734011               -74.002939
# 1         Berry St & N 8 St               40.719009               -73.958525
# 2           W 52 St & 9 Ave               40.764618               -73.987895
# 3   E 51 St & Lexington Ave               40.757148               -73.972078
# 4  Washington Pl & Broadway               40.729039               -73.994046
#
#    end station id         end station name  end station latitude  \
# ...

# %%
tripduration36 = data36.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration36.head()
# Out:
#    birth year  tripduration
# 0      1885.0    901.044643
# 1      1887.0   1284.800000
# 2      1888.0    701.966667
# 3      1894.0    284.000000
# 4      1899.0    873.421053

# %%
tripduration['06-2016'] = tripduration36['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data37 = pd.read_csv('/Users/jenny/Desktop/citibike/201607-citibike-tripdata.csv')

# %%
data37.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           704  7/1/2016 00:00:02  7/1/2016 00:11:47               459
# 1           492  7/1/2016 00:00:18  7/1/2016 00:08:31               293
# 2           191  7/1/2016 00:00:19  7/1/2016 00:03:31              3090
# 3           687  7/1/2016 00:00:24  7/1/2016 00:11:52               459
# 4           609  7/1/2016 00:00:31  7/1/2016 00:10:40               284
#
#       start station name  start station latitude  start station longitude  \
# 0       W 20 St & 11 Ave               40.746745               -74.007756
# 1  Lafayette St & E 8 St               40.730287               -73.990765
# 2    N 8 St & Driggs Ave               40.717746               -73.956001
# 3       W 20 St & 11 Ave               40.746745               -74.007756
# 4  Greenwich Ave & 8 Ave               40.739017               -74.002638
#
#    end station id             end station name  end station latitude  \
# ...

# %%
tripduration37 = data37.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration37.head()
# Out:
#    birth year  tripduration
# 0      1885.0   1053.026087
# 1      1888.0    835.741935
# 2      1893.0   1337.500000
# 3      1894.0    247.000000
# 4      1899.0    961.350000

# %%
tripduration['07-2016'] = tripduration37['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data38 = pd.read_csv('/Users/jenny/Desktop/citibike/201608-citibike-tripdata.csv')

# %%
data38.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           288  8/1/2016 00:01:22  8/1/2016 00:06:11               302
# 1           457  8/1/2016 00:01:43  8/1/2016 00:09:21               285
# 2           278  8/1/2016 00:02:10  8/1/2016 00:06:49               539
# 3           862  8/1/2016 00:02:13  8/1/2016 00:16:36               280
# 4           407  8/1/2016 00:02:21  8/1/2016 00:09:09               161
#
#                start station name  start station latitude  \
# 0               Avenue D & E 3 St               40.720828
# 1              Broadway & E 14 St               40.734546
# 2  Metropolitan Ave & Bedford Ave               40.715348
# 3                 E 10 St & 5 Ave               40.733320
# 4           LaGuardia Pl & W 3 St               40.729170
#
#    start station longitude  end station id     end station name  \
# 0               -73.977932             428       E 3 St & 1 Ave
# ...

# %%
tripduration38 = data38.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration38.head()
# Out:
#    birth year  tripduration
# 0      1885.0   1067.900000
# 1      1888.0    859.527778
# 2      1893.0   2407.000000
# 3      1894.0    386.200000
# 4      1896.0    937.500000

# %%
tripduration['08-2016'] = tripduration38['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data39 = pd.read_csv('/Users/jenny/Desktop/citibike/201609-citibike-tripdata.csv')

# %%
data39.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           975  9/1/2016 00:00:02  9/1/2016 00:16:18               312
# 1          1220  9/1/2016 00:00:04  9/1/2016 00:20:25               316
# 2           308  9/1/2016 00:00:19  9/1/2016 00:05:27               479
# 3           250  9/1/2016 00:00:25  9/1/2016 00:04:35               297
# 4           439  9/1/2016 00:00:25  9/1/2016 00:07:45               494
#
#        start station name  start station latitude  start station longitude  \
# 0   Allen St & Stanton St               40.722055               -73.989111
# 1  Fulton St & William St               40.709560               -74.006536
# 2         9 Ave & W 45 St               40.760193               -73.991255
# 3         E 15 St & 3 Ave               40.734232               -73.986923
# 4         W 26 St & 8 Ave               40.747348               -73.997236
#
#    end station id           end station name  end station latitude  \
# ...

# %%
tripduration39 = data39.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration39.head()
# Out:
#    birth year  tripduration
# 0      1885.0    976.016949
# 1      1886.0   1530.000000
# 2      1888.0    687.464286
# 3      1893.0    175.000000
# 4      1894.0    367.000000

# %%
tripduration['09-2016'] = tripduration39['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data40 = pd.read_csv('/Users/jenny/Desktop/citibike/201610-citibike-tripdata.csv')

# %%
data40.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            328  2016-10-01 00:00:07  2016-10-01 00:05:35               471
# 1            398  2016-10-01 00:00:11  2016-10-01 00:06:49              3147
# 2            430  2016-10-01 00:00:14  2016-10-01 00:07:25               345
# 3            351  2016-10-01 00:00:21  2016-10-01 00:06:12              3307
# 4           2693  2016-10-01 00:00:21  2016-10-01 00:45:15              3428
#
#         Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0  Grand St & Havemeyer St               40.712868               -73.956981
# 1          E 85 St & 3 Ave               40.778012               -73.954071
# 2          W 13 St & 6 Ave               40.736494               -73.997044
# 3   West End Ave & W 94 St               40.794165               -73.974124
# 4          8 Ave & W 16 St               40.740983               -74.001702
#
# ...

# %%
tripduration40 = data40.groupby(['Birth Year'], as_index=False)['Trip Duration'].mean()
tripduration40.head()
# Out:
#    Birth Year  Trip Duration
# 0      1885.0     953.861702
# 1      1886.0    1094.000000
# 2      1888.0     855.958333
# 3      1893.0     779.000000
# 4      1895.0    1109.500000

# %%
tripduration['10-2016'] = tripduration40['Trip Duration']
tripduration.to_csv('avgtripduration.csv')

# %%
data41 = pd.read_csv('/Users/jenny/Desktop/citibike/201611-citibike-tripdata.csv')

# %%
data41.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            331  2016-11-01 00:00:08  2016-11-01 00:05:40               324
# 1            740  2016-11-01 00:00:08  2016-11-01 00:12:29               161
# 2            229  2016-11-01 00:00:11  2016-11-01 00:04:00              3074
# 3            155  2016-11-01 00:00:18  2016-11-01 00:02:53              3357
# 4            772  2016-11-01 00:00:23  2016-11-01 00:13:15               346
#
#             Start Station Name  Start Station Latitude  \
# 0      DeKalb Ave & Hudson Ave               40.689888
# 1        LaGuardia Pl & W 3 St               40.729170
# 2  Montrose Ave & Bushwick Ave               40.707678
# 3     W 106 St & Amsterdam Ave               40.800836
# 4          Bank St & Hudson St               40.736529
#
#    Start Station Longitude  End Station ID              End Station Name  \
# 0               -73.981013             419        Carlton Ave & Park Ave
# ...

# %%
tripduration41 = data41.groupby(['Birth Year'], as_index=False)['Trip Duration'].mean()
tripduration41.head()
# Out:
#    Birth Year  Trip Duration
# 0      1885.0    1148.626506
# 1      1886.0    1229.000000
# 2      1888.0     485.733333
# 3      1893.0     711.142857
# 4      1895.0     829.175439

# %%
tripduration['11-2016'] = tripduration41['Trip Duration']
tripduration.to_csv('avgtripduration.csv')

# %%
data42 = pd.read_csv('/Users/jenny/Desktop/citibike/201612-citibike-tripdata.csv')

# %%
data42.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            528  2016-12-01 00:00:04  2016-12-01 00:08:52               499
# 1            218  2016-12-01 00:00:28  2016-12-01 00:04:06              3418
# 2            399  2016-12-01 00:00:39  2016-12-01 00:07:19               297
# 3            254  2016-12-01 00:00:44  2016-12-01 00:04:59               405
# 4           1805  2016-12-01 00:00:54  2016-12-01 00:31:00               279
#
#               Start Station Name  Start Station Latitude  \
# 0             Broadway & W 60 St               40.769155
# 1   Plaza St West & Flatbush Ave               40.675021
# 2                E 15 St & 3 Ave               40.734232
# 3  Washington St & Gansevoort St               40.739323
# 4           Peck Slip & Front St               40.707873
#
#    Start Station Longitude  End Station ID               End Station Name  \
# 0               -73.981918             228                E 48 St & 3 Ave
# ...

# %%
tripduration42 = data42.groupby(['Birth Year'], as_index=False)['Trip Duration'].mean()
tripduration42.head()
# Out:
#    Birth Year  Trip Duration
# 0      1885.0    1960.642857
# 1      1886.0     617.000000
# 2      1888.0     792.272727
# 3      1893.0     691.230769
# 4      1895.0     690.600000

# %%
tripduration['12-2016'] = tripduration42['Trip Duration']
tripduration.to_csv('avgtripduration.csv')

# %%
data43 = pd.read_csv('/Users/jenny/Desktop/citibike/201701-citibike-tripdata.csv')

# %%
data43.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            680  2017-01-01 00:00:21  2017-01-01 00:11:41              3226
# 1           1282  2017-01-01 00:00:45  2017-01-01 00:22:08              3263
# 2            648  2017-01-01 00:00:57  2017-01-01 00:11:46              3143
# 3            631  2017-01-01 00:01:10  2017-01-01 00:11:42              3143
# 4            621  2017-01-01 00:01:25  2017-01-01 00:11:47              3143
#
#             Start Station Name  Start Station Latitude  \
# 0  W 82 St & Central Park West               40.782750
# 1       Cooper Square & E 7 St               40.729236
# 2              5 Ave & E 78 St               40.776829
# 3              5 Ave & E 78 St               40.776829
# 4              5 Ave & E 78 St               40.776829
#
#    Start Station Longitude  End Station ID             End Station Name  \
# 0               -73.971370            3165  Central Park West & W 72 St
# ...

# %%
tripduration43 = data43.groupby(['Birth Year'], as_index=False)['Trip Duration'].mean()
tripduration43.head()
# Out:
#    Birth Year  Trip Duration
# 0      1885.0     899.339286
# 1      1886.0    1621.900000
# 2      1893.0     709.500000
# 3      1895.0     666.333333
# 4      1899.0     974.480000

# %%
tripduration['01-2017'] = tripduration43['Trip Duration']
tripduration.to_csv('avgtripduration.csv')

# %%
data44 = pd.read_csv('/Users/jenny/Desktop/citibike/201702-citibike-tripdata.csv')

# %%
data44.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0           1087  2017-02-01 00:00:13  2017-02-01 00:18:20               345
# 1            704  2017-02-01 00:00:31  2017-02-01 00:12:15              3295
# 2            212  2017-02-01 00:00:34  2017-02-01 00:04:06               336
# 3           1140  2017-02-01 00:00:44  2017-02-01 00:19:44               484
# 4            320  2017-02-01 00:00:42  2017-02-01 00:06:02               490
#
#             Start Station Name  Start Station Latitude  \
# 0              W 13 St & 6 Ave               40.736494
# 1     Central Park W & W 96 St               40.791270
# 2  Sullivan St & Washington Sq               40.730477
# 3              W 44 St & 5 Ave               40.755003
# 4              8 Ave & W 33 St               40.751551
#
#    Start Station Longitude  End Station ID          End Station Name  \
# 0               -73.997044             305           E 58 St & 3 Ave
# ...

# %%
tripduration44 = data44.groupby(['Birth Year'], as_index=False)['Trip Duration'].mean()
tripduration44.head()
# Out:
#    Birth Year  Trip Duration
# 0      1858.0   29372.000000
# 1      1885.0     820.954545
# 2      1886.0     779.375000
# 3      1888.0     308.750000
# 4      1893.0     671.888889

# %%
tripduration['02-2017'] = tripduration44['Trip Duration']
tripduration.to_csv('avgtripduration.csv')

# %%
data45 = pd.read_csv('/Users/jenny/Desktop/citibike/201703-citibike-tripdata.csv')

# %%
data45.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0           1893  2017-03-01 00:00:32  2017-03-01 00:32:06              2009
# 1            223  2017-03-01 00:01:09  2017-03-01 00:04:53               127
# 2           1665  2017-03-01 00:01:27  2017-03-01 00:29:12               174
# 3            100  2017-03-01 00:01:29  2017-03-01 00:03:10               316
# 4           1229  2017-03-01 00:01:33  2017-03-01 00:22:02               536
#
#          Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0  Catherine St & Monroe St               40.711174               -73.996826
# 1     Barrow St & Hudson St               40.731724               -74.006744
# 2           E 25 St & 1 Ave               40.738177               -73.977387
# 3    Fulton St & William St               40.709560               -74.006536
# 4           1 Ave & E 30 St               40.741444               -73.975361
#
# ...

# %%
tripduration45 = data45.groupby(['Birth Year'], as_index=False)['Trip Duration'].mean()
tripduration45.head()
# Out:
#    Birth Year  Trip Duration
# 0      1885.0     799.948718
# 1      1886.0     963.500000
# 2      1888.0     389.666667
# 3      1893.0     758.533333
# 4      1895.0     531.000000

# %%
tripduration['03-2017'] = tripduration45['Trip Duration']
tripduration.to_csv('avgtripduration.csv')

# %%
data46 = pd.read_csv('/Users/jenny/Desktop/citibike/201704-citibike-tripdata.csv')

# %%
data46.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           195  2017-04-01 00:00:58  2017-04-01 00:04:14               217
# 1           585  2017-04-01 00:01:54  2017-04-01 00:11:40               490
# 2           665  2017-04-01 00:01:56  2017-04-01 00:13:01               504
# 3           262  2017-04-01 00:02:24  2017-04-01 00:06:47               445
# 4           134  2017-04-01 00:02:36  2017-04-01 00:04:50              3423
#
#                 start station name  start station latitude  \
# 0                    Old Fulton St               40.702772
# 1                  8 Ave & W 33 St               40.751551
# 2                  1 Ave & E 16 St               40.732219
# 3               E 10 St & Avenue A               40.727408
# 4  West Drive & Prospect Park West               40.661063
#
#    start station longitude  end station id           end station name  \
# 0               -73.993836             430           York St & Jay St
# ...

# %%
tripduration46 = data46.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration46.head()
# Out:
#    birth year  tripduration
# 0      1885.0    734.900000
# 1      1886.0  12920.200000
# 2      1888.0    988.111111
# 3      1893.0    745.578947
# 4      1895.0    935.600000

# %%
tripduration['04-2017'] = tripduration46['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data47 = pd.read_csv('/Users/jenny/Desktop/citibike/201705-citibike-tripdata.csv')

# %%
data47.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           254  2017-05-01 00:00:13  2017-05-01 00:04:27               511
# 1           248  2017-05-01 00:00:19  2017-05-01 00:04:28               511
# 2          1120  2017-05-01 00:00:19  2017-05-01 00:19:00               242
# 3           212  2017-05-01 00:00:24  2017-05-01 00:03:56               168
# 4           686  2017-05-01 00:00:29  2017-05-01 00:11:55               494
#
#            start station name  start station latitude  \
# 0          E 14 St & Avenue B               40.729387
# 1          E 14 St & Avenue B               40.729387
# 2  Carlton Ave & Flushing Ave               40.697787
# 3             W 18 St & 6 Ave               40.739713
# 4             W 26 St & 8 Ave               40.747348
#
#    start station longitude  end station id          end station name  \
# 0               -73.977724             394         E 9 St & Avenue C
# ...

# %%
tripduration47 = data47.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration47.head()
# Out:
#    birth year  tripduration
# 0      1885.0    740.125000
# 1      1886.0   1456.500000
# 2      1888.0   1183.250000
# 3      1893.0    581.550000
# 4      1895.0    874.461538

# %%
tripduration['05-2017'] = tripduration47['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data48 = pd.read_csv('/Users/jenny/Desktop/citibike/201706-citibike-tripdata.csv')

# %%
data48.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          1397  2017-06-01 00:00:02  2017-06-01 00:23:19               515
# 1          1103  2017-06-01 00:00:13  2017-06-01 00:18:37               488
# 2          1810  2017-06-01 00:00:20  2017-06-01 00:30:31               461
# 3          1760  2017-06-01 00:00:24  2017-06-01 00:29:45              2009
# 4          2165  2017-06-01 00:00:33  2017-06-01 00:36:38               360
#
#          start station name  start station latitude  start station longitude  \
# 0          W 43 St & 10 Ave               40.760094               -73.994618
# 1           W 39 St & 9 Ave               40.756458               -73.993722
# 2           E 20 St & 2 Ave               40.735877               -73.982050
# 3  Catherine St & Monroe St               40.711174               -73.996826
# 4      William St & Pine St               40.707179               -74.008873
#
# ...

# %%
tripduration48 = data48.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration48.head()
# Out:
#    birth year  tripduration
# 0      1885.0    996.818182
# 1      1886.0   1194.545455
# 2      1887.0   1468.600000
# 3      1893.0    600.222222
# 4      1895.0   1154.200000

# %%
tripduration['06-2017'] = tripduration48['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data49 = pd.read_csv('/Users/jenny/Desktop/citibike/201707-citibike-tripdata.csv')

# %%
data49.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           364  2017-07-01 00:00:00  2017-07-01 00:06:05               539
# 1          2142  2017-07-01 00:00:03  2017-07-01 00:35:46               293
# 2           328  2017-07-01 00:00:08  2017-07-01 00:05:37              3242
# 3          2530  2017-07-01 00:00:11  2017-07-01 00:42:22              2002
# 4          2534  2017-07-01 00:00:15  2017-07-01 00:42:29              2002
#
#                start station name  start station latitude  \
# 0  Metropolitan Ave & Bedford Ave               40.715348
# 1           Lafayette St & E 8 St               40.730207
# 2      Schermerhorn St & Court St               40.691029
# 3    Wythe Ave & Metropolitan Ave               40.716887
# 4    Wythe Ave & Metropolitan Ave               40.716887
#
#    start station longitude  end station id          end station name  \
# 0               -73.960241            3107  Bedford Ave & Nassau Ave
# ...

# %%
tripduration49 = data49.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration49.head()
# Out:
#    birth year  tripduration
# 0      1874.0   1379.500000
# 1      1885.0    805.542373
# 2      1886.0   1226.909091
# 3      1887.0    727.523810
# 4      1893.0    588.250000

# %%
tripduration['07-2017'] = tripduration49['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data50 = pd.read_csv('/Users/jenny/Desktop/citibike/201708-citibike-tripdata.csv')

# %%
data50.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          2110  2017-08-01 00:00:00  2017-08-01 00:35:11               470
# 1           160  2017-08-01 00:00:10  2017-08-01 00:02:51               348
# 2          1644  2017-08-01 00:00:17  2017-08-01 00:27:41              3165
# 3           323  2017-08-01 00:00:27  2017-08-01 00:05:51               389
# 4           109  2017-08-01 00:00:41  2017-08-01 00:02:31              3145
#
#             start station name  start station latitude  \
# 0              W 20 St & 8 Ave               40.743453
# 1       W Broadway & Spring St               40.724910
# 2  Central Park West & W 72 St               40.775794
# 3          Broadway & Berry St               40.710446
# 4           E 84 St & Park Ave               40.778627
#
#    start station longitude  end station id              end station name  \
# 0               -74.000040            3289       W 90 St & Amsterdam Ave
# ...

# %%
tripduration50 = data50.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration50.head()
# Out:
#    birth year  tripduration
# 0      1885.0    761.452381
# 1      1886.0   1478.380952
# 2      1887.0    669.454545
# 3      1888.0   1031.076923
# 4      1890.0   5906.000000

# %%
tripduration['08-2017'] = tripduration50['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data51 = pd.read_csv('/Users/jenny/Desktop/citibike/201709-citibike-tripdata.csv')

# %%
data51.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           362  2017-09-01 00:00:17  2017-09-01 00:06:19              3331
# 1           188  2017-09-01 00:00:21  2017-09-01 00:03:30              3101
# 2           305  2017-09-01 00:00:25  2017-09-01 00:05:30              3140
# 3           223  2017-09-01 00:00:52  2017-09-01 00:04:36               236
# 4           758  2017-09-01 00:01:01  2017-09-01 00:13:40              3427
#
#          start station name  start station latitude  start station longitude  \
# 0   Riverside Dr & W 104 St               40.801343               -73.971146
# 1     N 12 St & Bedford Ave               40.720798               -73.954847
# 2           1 Ave & E 78 St               40.771404               -73.953517
# 3       St Marks Pl & 2 Ave               40.728419               -73.987140
# 4  Lafayette St & Jersey St               40.724305               -73.996010
#
# ...

# %%
tripduration51 = data51.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration51.head()
# Out:
#    birth year  tripduration
# 0      1885.0    957.244898
# 1      1886.0    955.000000
# 2      1887.0   1728.090909
# 3      1888.0   1185.750000
# 4      1889.0   1082.000000

# %%
tripduration['09-2017'] = tripduration51['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data52 = pd.read_csv('/Users/jenny/Desktop/citibike/201710-citibike-tripdata.csv')

# %%
data52.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           457  2017-10-01 00:00:00  2017-10-01 00:07:38               479
# 1          6462  2017-10-01 00:00:20  2017-10-01 01:48:03               279
# 2           761  2017-10-01 00:00:27  2017-10-01 00:13:09               504
# 3          1193  2017-10-01 00:00:29  2017-10-01 00:20:22              3236
# 4          2772  2017-10-01 00:00:32  2017-10-01 00:46:44              2006
#
#        start station name  start station latitude  start station longitude  \
# 0         9 Ave & W 45 St               40.760193               -73.991255
# 1    Peck Slip & Front St               40.707873               -74.001670
# 2         1 Ave & E 16 St               40.732219               -73.981656
# 3      W 42 St & Dyer Ave               40.758985               -73.993800
# 4  Central Park S & 6 Ave               40.765909               -73.976342
#
# ...

# %%
tripduration52 = data52.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration52.head()
# Out:
#    birth year  tripduration
# 0      1885.0    898.368421
# 1      1887.0   1126.500000
# 2      1888.0   1149.200000
# 3      1889.0   1379.000000
# 4      1890.0  12629.333333

# %%
tripduration['10-2017'] = tripduration52['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data53 = pd.read_csv('/Users/jenny/Desktop/citibike/201711-citibike-tripdata.csv')

# %%
data53.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           297  2017-11-01 00:00:01  2017-11-01 00:04:59               418
# 1           269  2017-11-01 00:00:01  2017-11-01 00:04:30              3556
# 2           285  2017-11-01 00:00:04  2017-11-01 00:04:50               275
# 3           478  2017-11-01 00:00:13  2017-11-01 00:08:11              3545
# 4           574  2017-11-01 00:00:20  2017-11-01 00:09:54               458
#
#             start station name  start station latitude  \
# 0           Front St & Gold St               40.702240
# 1               24 St & 41 Ave               40.752709
# 2  Washington Ave & Greene Ave               40.686501
# 3          Broadway & W 122 St               40.812056
# 4             11 Ave & W 27 St               40.751396
#
#    start station longitude  end station id          end station name  \
# 0               -73.982578             414   Pearl St & Anchorage Pl
# ...

# %%
tripduration53 = data53.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration53.head()
# Out:
#    birth year  tripduration
# 0      1884.0   1404.000000
# 1      1885.0    890.137931
# 2      1886.0   1098.400000
# 3      1887.0   1333.847458
# 4      1890.0    630.000000

# %%
tripduration['11-2017'] = tripduration53['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data54 = pd.read_csv('/Users/jenny/Desktop/citibike/201712-citibike-tripdata.csv')

# %%
data54.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           256  2017-12-01 00:00:00  2017-12-01 00:04:17               324
# 1           325  2017-12-01 00:00:17  2017-12-01 00:05:43               470
# 2           967  2017-12-01 00:00:19  2017-12-01 00:16:26               347
# 3           125  2017-12-01 00:00:20  2017-12-01 00:02:26              3077
# 4           451  2017-12-01 00:00:28  2017-12-01 00:08:00               368
#
#             start station name  start station latitude  \
# 0      DeKalb Ave & Hudson Ave               40.689888
# 1              W 20 St & 8 Ave               40.743453
# 2  Greenwich St & W Houston St               40.728846
# 3         Stagg St & Union Ave               40.708771
# 4           Carmine St & 6 Ave               40.730386
#
#    start station longitude  end station id        end station name  \
# 0               -73.981013             262         Washington Park
# ...

# %%
tripduration54 = data54.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration54.head()
# Out:
#    birth year  tripduration
# 0      1885.0    822.592593
# 1      1887.0    669.311475
# 2      1889.0   1115.000000
# 3      1894.0    652.000000
# 4      1899.0   1281.000000

# %%
tripduration['12-2017'] = tripduration54['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data55 = pd.read_csv('/Users/jenny/Desktop/citibike/201801_citibikejc_tripdata.csv')

# %%
data55.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           132  2018-01-01 00:01:46  2018-01-01 00:03:58              3186
# 1           560  2018-01-01 01:27:17  2018-01-01 01:36:38              3276
# 2           294  2018-01-01 01:29:03  2018-01-01 01:33:58              3195
# 3           197  2018-01-01 01:59:32  2018-01-01 02:02:49              3211
# 4           932  2018-01-01 02:06:18  2018-01-01 02:21:50              3183
#
#   start station name  start station latitude  start station longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1   Marin Light Rail               40.714584               -74.042817
# 2            Sip Ave               40.730743               -74.063784
# 3         Newark Ave               40.721525               -74.046305
# 4     Exchange Place               40.716247               -74.033459
#
#    end station id       end station name  end station latitude  \
# ...

# %%
tripduration55 = data55.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration55.head()
# Out:
#    birth year  tripduration
# 0      1887.0    377.181818
# 1      1931.0    227.000000
# 2      1941.0    386.444444
# 3      1946.0    418.750000
# 4      1947.0    439.500000

# %%
tripduration['01-2018'] = tripduration55['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data56 = pd.read_csv('/Users/jenny/Desktop/citibike/201801_citibikenyc_tripdata.csv')

# %%
data56.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           196  2018-01-01 00:01:51  2018-01-01 00:05:07               315
# 1           207  2018-01-01 00:02:44  2018-01-01 00:06:11              3224
# 2           613  2018-01-01 00:03:15  2018-01-01 00:13:28               386
# 3           375  2018-01-01 00:06:44  2018-01-01 00:12:59               466
# 4           402  2018-01-01 00:06:57  2018-01-01 00:13:40               438
#
#          start station name  start station latitude  start station longitude  \
# 0  South St & Gouverneur Ln               40.703554               -74.006702
# 1       W 13 St & Hudson St               40.739974               -74.005139
# 2      Centre St & Worth St               40.714948               -74.002345
# 3           W 25 St & 6 Ave               40.743954               -73.991449
# 4       St Marks Pl & 1 Ave               40.727791               -73.985649
#
# ...

# %%
tripduration56 = data56.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration56.head()
# Out:
#    birth year  tripduration
# 0      1885.0    666.969697
# 1      1886.0   1265.000000
# 2      1887.0    784.132075
# 3      1894.0    752.909091
# 4      1899.0   1414.200000

# %%
tripduration['01-2018 (2)'] = tripduration56['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data57 = pd.read_csv('/Users/jenny/Desktop/citibike/201802_citibikejc_tripdata.csv')

# %%
data57.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           386  2018-02-01 00:30:21  2018-02-01 00:36:47              3205
# 1           724  2018-02-01 00:59:14  2018-02-01 01:11:19              3225
# 2           452  2018-02-01 03:50:25  2018-02-01 03:57:57              3280
# 3           358  2018-02-01 05:06:52  2018-02-01 05:12:51              3279
# 4           218  2018-02-01 05:14:48  2018-02-01 05:18:26              3267
#
#       start station name  start station latitude  start station longitude  \
# 0      JC Medical Center               40.716540               -74.049638
# 1  Baldwin at Montgomery               40.723659               -74.064194
# 2            Astor Place               40.719282               -74.071262
# 3            Dixon Mills               40.721630               -74.049968
# 4           Morris Canal               40.712419               -74.038526
#
# ...

# %%
tripduration57 = data57.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration57.head()
# Out:
#    birth year  tripduration
# 0      1887.0    401.000000
# 1      1931.0    213.818182
# 2      1941.0    373.428571
# 3      1947.0    473.000000
# 4      1948.0   1010.000000

# %%
tripduration['02-2018'] = tripduration57['tripduration']
tripduration.to_csv('avgtripduration.csv')

# %%
data58 = pd.read_csv('/Users/jenny/Desktop/citibike/201802_citibikenyc_tripdata.csv')

# %%
data58.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           509  2018-02-01 00:00:04  2018-02-01 00:08:34              3458
# 1           513  2018-02-01 00:00:15  2018-02-01 00:08:49               459
# 2           516  2018-02-01 00:00:16  2018-02-01 00:08:52               459
# 3           196  2018-02-01 00:00:16  2018-02-01 00:03:32              3318
# 4           491  2018-02-01 00:00:20  2018-02-01 00:08:31               499
#
#    start station name  start station latitude  start station longitude  \
# 0     W 55 St & 6 Ave               40.763094               -73.978350
# 1    W 20 St & 11 Ave               40.746745               -74.007756
# 2    W 20 St & 11 Ave               40.746745               -74.007756
# 3     2 Ave & E 96 St               40.783964               -73.947167
# 4  Broadway & W 60 St               40.769155               -73.981918
#
#    end station id         end station name  end station latitude  \
# ...

# %%
tripduration58 = data58.groupby(['birth year'], as_index=False)['tripduration'].mean()
tripduration58.head()
# Out:
#    birth year  tripduration
# 0      1885.0    661.444444
# 1      1886.0    467.400000
# 2      1887.0    693.038462
# 3      1888.0   1016.250000
# 4      1889.0   1411.000000

# %%
tripduration['02-2018 (2)'] = tripduration58['tripduration']
tripduration.to_csv('avgtripduration.csv')
