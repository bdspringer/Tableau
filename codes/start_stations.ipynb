# %%
import csv
import pandas as pd

# %%
data = pd.read_csv('/Users/jenny/Desktop/citibike/2013-07-CitiBiketripdata.csv')

# %%
data.head()
# Out:
#    tripduration    starttime     stoptime  start station id  \
# 0           634  7/1/13 0:00  7/1/13 0:10               164
# 1          1547  7/1/13 0:00  7/1/13 0:25               388
# 2           178  7/1/13 0:01  7/1/13 0:04               293
# 3          1580  7/1/13 0:01  7/1/13 0:27               531
# 4           757  7/1/13 0:01  7/1/13 0:13               382
#
#         start station name  start station latitude  start station longitude  \
# 0          E 47 St & 2 Ave               40.753231               -73.970325
# 1         W 26 St & 10 Ave               40.749718               -74.002950
# 2    Lafayette St & E 8 St               40.730287               -73.990765
# 3   Forsyth St & Broome St               40.718939               -73.992663
# 4  University Pl & E 14 St               40.734927               -73.992005
#
#    end station id         end station name  end station latitude  \
# 0             504          1 Ave & E 15 St             40.732219
# ...

# %%
topstation = data.groupby(['start station id']).size().reset_index(name='counts')
topstation.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 234               459    8049
# 271               497    7814
# 204               426    7387
# 291               519    7290
# 78                285    7167
# 293               521    7048
# 82                293    6979
# 115               327    6829
# 273               499    6294
# 265               490    6259

# %%
bottomstation = data.groupby(['start station id']).size().reset_index(name='counts')
bottomstation.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 318              2005     116
# 5                 119     117
# 314              2001     162
# 109               321     175
# 208               431     225
# 220               443     294
# 156               372     295
# 79                289     329
# 213               436     331
# 173               392     333

# %%
data2 = pd.read_csv('/Users/jenny/Desktop/citibike/2013-08-CitiBiketripdata.csv')

# %%
data2.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           664  2013-08-01 00:00:00  2013-08-01 00:11:04               449
# 1          2115  2013-08-01 00:00:01  2013-08-01 00:35:16               254
# 2           385  2013-08-01 00:00:03  2013-08-01 00:06:28               460
# 3           653  2013-08-01 00:00:10  2013-08-01 00:11:03               398
# 4           954  2013-08-01 00:00:11  2013-08-01 00:16:05               319
#
#          start station name  start station latitude  start station longitude  \
# 0           W 52 St & 9 Ave               40.764618               -73.987895
# 1           W 11 St & 6 Ave               40.735324               -73.998004
# 2        S 4 St & Wythe Ave               40.712859               -73.965903
# 3  Atlantic Ave & Furman St               40.691652               -73.999979
# 4       Park Pl & Church St               40.713361               -74.009376
#
# ...

# %%
topstation2 = data2.groupby(['start station id']).size().reset_index(name='counts')
topstation2.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 271               497    9874
# 292               519    9721
# 234               459    9631
# 204               426    9253
# 82                293    9020
# 78                285    8443
# 294               521    7993
# 265               490    7840
# 115               327    7420
# 15                151    7417

# %%
bottomstation2 = data2.groupby(['start station id']).size().reset_index(name='counts')
bottomstation2.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 319              2005     115
# 315              2001     185
# 5                 119     185
# 109               321     204
# 276               502     214
# 156               372     280
# 213               436     314
# 130               344     372
# 208               431     375
# 79                289     386

# %%
data3 = pd.read_csv('/Users/jenny/Desktop/citibike/2013-09-CitiBiketripdata.csv')

# %%
data3.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          1010  2013-09-01 00:00:02  2013-09-01 00:16:52               254
# 1          1443  2013-09-01 00:00:09  2013-09-01 00:24:12               151
# 2          1387  2013-09-01 00:00:16  2013-09-01 00:23:23               352
# 3           405  2013-09-01 00:00:18  2013-09-01 00:07:03               490
# 4           270  2013-09-01 00:00:20  2013-09-01 00:04:50               236
#
#          start station name  start station latitude  start station longitude  \
# 0           W 11 St & 6 Ave               40.735324               -73.998004
# 1  Cleveland Pl & Spring St               40.721816               -73.997203
# 2           W 56 St & 6 Ave               40.763406               -73.977225
# 3           8 Ave & W 33 St               40.751551               -73.993934
# 4       St Marks Pl & 2 Ave               40.728419               -73.987140
#
# ...

# %%
topstation3 = data3.groupby(['start station id']).size().reset_index(name='counts')
topstation3.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 234               459   10532
# 292               519   10288
# 271               497    9890
# 82                293    9814
# 294               521    9252
# 204               426    9248
# 78                285    8152
# 163               382    7837
# 212               435    7828
# 162               380    7817

# %%
bottomstation3 = data3.groupby(['start station id']).size().reset_index(name='counts')
bottomstation3.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 319              2005      87
# 109               321     194
# 315              2001     197
# 208               431     278
# 5                 119     280
# 156               372     297
# 79                289     341
# 213               436     379
# 129               343     383
# 220               443     390

# %%
data4 = pd.read_csv('/Users/jenny/Desktop/citibike/2013-10-CitiBiketripdata.csv')

# %%
data4.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           326  2013-10-01 00:01:08  2013-10-01 00:06:34               239
# 1           729  2013-10-01 00:01:21  2013-10-01 00:13:30               322
# 2           520  2013-10-01 00:01:24  2013-10-01 00:10:04               174
# 3           281  2013-10-01 00:01:25  2013-10-01 00:06:06               430
# 4           196  2013-10-01 00:01:27  2013-10-01 00:04:43               403
#
#          start station name  start station latitude  start station longitude  \
# 0  Willoughby St & Fleet St               40.691966               -73.981302
# 1   Clinton St & Tillary St               40.696192               -73.991218
# 2           E 25 St & 1 Ave               40.738177               -73.977387
# 3          York St & Jay St               40.701485               -73.986569
# 4            E 2 St & 2 Ave               40.725029               -73.990697
#
# ...

# %%
topstation4 = data4.groupby(['start station id']).size().reset_index(name='counts')
topstation4.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 294               521   11196
# 292               519   11169
# 271               497   10606
# 82                293   10456
# 234               459    9792
# 78                285    9114
# 163               382    8928
# 204               426    8065
# 212               435    7969
# 301               528    7902

# %%
bottomstation4 = data4.groupby(['start station id']).size().reset_index(name='counts')
bottomstation4.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 319              2005      96
# 109               321     208
# 315              2001     218
# 5                 119     269
# 156               372     280
# 46                245     292
# 220               443     296
# 79                289     313
# 208               431     317
# 73                279     376

# %%
data5 = pd.read_csv('/Users/jenny/Desktop/citibike/2013-11-CitiBiketripdata.csv')

# %%
data5.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           504  2013-11-01 00:00:17  2013-11-01 00:08:41               326
# 1           747  2013-11-01 00:00:20  2013-11-01 00:12:47               375
# 2          1005  2013-11-01 00:00:30  2013-11-01 00:17:15               264
# 3           622  2013-11-01 00:01:29  2013-11-01 00:11:51               472
# 4          1454  2013-11-01 00:01:37  2013-11-01 00:25:51               293
#
#         start station name  start station latitude  start station longitude  \
# 0          E 11 St & 1 Ave               40.729538               -73.984267
# 1  Mercer St & Bleecker St               40.726795               -73.996951
# 2     Maiden Ln & Pearl St               40.707065               -74.007319
# 3       E 32 St & Park Ave               40.745712               -73.981948
# 4    Lafayette St & E 8 St               40.730287               -73.990765
#
# ...

# %%
topstation5 = data5.groupby(['start station id']).size().reset_index(name='counts')
topstation5.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 294               521    8011
# 271               497    7256
# 292               519    7235
# 82                293    6384
# 212               435    6365
# 183               402    5750
# 78                285    5620
# 234               459    5617
# 265               490    5376
# 252               477    5303

# %%
bottomstation5 = data5.groupby(['start station id']).size().reset_index(name='counts')
bottomstation5.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 319              2005      39
# 109               321      59
# 199               419      97
# 208               431     117
# 315              2001     126
# 220               443     144
# 5                 119     152
# 156               372     187
# 79                289     195
# 11                144     221

# %%
data6 = pd.read_csv('/Users/jenny/Desktop/citibike/2013-12-CitiBiketripdata.csv')

# %%
data6.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          1015  2013-12-01 00:00:03  2013-12-01 00:16:58               401
# 1           962  2013-12-01 00:00:07  2013-12-01 00:16:09               312
# 2           768  2013-12-01 00:00:15  2013-12-01 00:13:03               326
# 3           218  2013-12-01 00:00:49  2013-12-01 00:04:27              2021
# 4           550  2013-12-01 00:01:28  2013-12-01 00:10:38               439
#
#         start station name  start station latitude  start station longitude  \
# 0  Allen St & Rivington St               40.720196               -73.989978
# 1  Allen St & E Houston St               40.722055               -73.989111
# 2          E 11 St & 1 Ave               40.729538               -73.984267
# 3          W 45 St & 8 Ave               40.759291               -73.988597
# 4           E 4 St & 2 Ave               40.726281               -73.989780
#
# ...

# %%
topstation6 = data6.groupby(['start station id']).size().reset_index(name='counts')
topstation6.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 293               521    4905
# 291               519    4637
# 211               435    4508
# 270               497    4310
# 264               490    4084
# 82                293    4081
# 78                285    3725
# 182               402    3559
# 251               477    3538
# 15                151    3222

# %%
bottomstation6 = data6.groupby(['start station id']).size().reset_index(name='counts')
bottomstation6.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 198               419      42
# 318              2005      47
# 219               443      80
# 314              2001      81
# 207               431      98
# 11                144     104
# 5                 119     113
# 79                289     138
# 73                279     141
# 155               372     142

# %%
data7 = pd.read_csv('/Users/jenny/Desktop/citibike/2014-01-CitiBiketripdata.csv')

# %%
data7.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           471  2014-01-01 00:00:06  2014-01-01 00:07:57              2009
# 1          1494  2014-01-01 00:00:38  2014-01-01 00:25:32               536
# 2           464  2014-01-01 00:03:59  2014-01-01 00:11:43               228
# 3           373  2014-01-01 00:05:15  2014-01-01 00:11:28               519
# 4           660  2014-01-01 00:05:18  2014-01-01 00:16:18                83
#
#               start station name  start station latitude  \
# 0       Catherine St & Monroe St               40.711174
# 1                1 Ave & E 30 St               40.741444
# 2                E 48 St & 3 Ave               40.754601
# 3              Pershing Square N               40.751884
# 4  Atlantic Ave & Fort Greene Pl               40.683826
#
#    start station longitude  end station id          end station name  \
# 0               -73.996826             263  Elizabeth St & Hester St
# ...

# %%
topstation7 = data7.groupby(['start station id']).size().reset_index(name='counts')
topstation7.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 291               519    3634
# 293               521    3295
# 82                293    3178
# 211               435    3068
# 270               497    2764
# 264               490    2697
# 106               318    2519
# 182               402    2469
# 251               477    2368
# 160               379    2231

# %%
bottomstation7 = data7.groupby(['start station id']).size().reset_index(name='counts')
bottomstation7.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 318              2005      26
# 219               443      53
# 207               431      61
# 198               419      62
# 5                 119      92
# 11                144      93
# 155               372      94
# 30                218      96
# 314              2001     103
# 124               339     106

# %%
data8 = pd.read_csv('/Users/jenny/Desktop/citibike/2014-02-CitiBiketripdata.csv')

# %%
data8.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           382  2014-02-01 00:00:00  2014-02-01 00:06:22               294
# 1           372  2014-02-01 00:00:03  2014-02-01 00:06:15               285
# 2           591  2014-02-01 00:00:09  2014-02-01 00:10:00               247
# 3           583  2014-02-01 00:00:32  2014-02-01 00:10:15               357
# 4           223  2014-02-01 00:00:41  2014-02-01 00:04:24               401
#
#         start station name  start station latitude  start station longitude  \
# 0      Washington Square E               40.730494               -73.995721
# 1       Broadway & E 14 St               40.734546               -73.990741
# 2   Perry St & Bleecker St               40.735354               -74.004831
# 3       E 11 St & Broadway               40.732618               -73.991580
# 4  Allen St & Rivington St               40.720196               -73.989978
#
# ...

# %%
topstation8 = data8.groupby(['start station id']).size().reset_index(name='counts')
topstation8.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 82                293    2920
# 291               519    2719
# 270               497    2493
# 211               435    2403
# 293               521    2171
# 264               490    1944
# 251               477    1916
# 162               382    1808
# 15                151    1796
# 78                285    1795

# %%
bottomstation8 = data8.groupby(['start station id']).size().reset_index(name='counts')
bottomstation8.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 108               320       4
# 318              2005      36
# 219               443      41
# 72                278      45
# 207               431      54
# 197               418      56
# 155               372      57
# 5                 119      57
# 53                253      69
# 28                216      72

# %%
data9 = pd.read_csv('/Users/jenny/Desktop/citibike/2014-03-CitiBiketripdata.csv')

# %%
data9.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           949  2014-03-01 00:00:16  2014-03-01 00:16:05               317
# 1           533  2014-03-01 00:00:57  2014-03-01 00:09:50               457
# 2           122  2014-03-01 00:01:06  2014-03-01 00:03:08               146
# 3           134  2014-03-01 00:01:14  2014-03-01 00:03:28               146
# 4           997  2014-03-01 00:01:18  2014-03-01 00:17:55               150
#
#      start station name  start station latitude  start station longitude  \
# 0     E 6 St & Avenue B               40.724537               -73.981854
# 1    Broadway & W 58 St               40.766953               -73.981693
# 2  Hudson St & Reade St               40.716250               -74.009106
# 3  Hudson St & Reade St               40.716250               -74.009106
# 4     E 2 St & Avenue C               40.720874               -73.980858
#
#    end station id         end station name  end station latitude  \
# ...

# %%
topstation9 = data9.groupby(['start station id']).size().reset_index(name='counts')
topstation9.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 293               519    5208
# 82                293    5102
# 295               521    4782
# 212               435    4306
# 272               497    4067
# 265               490    3781
# 161               379    3680
# 78                285    3651
# 252               477    3369
# 106               318    3304

# %%
bottomstation9 = data9.groupby(['start station id']).size().reset_index(name='counts')
bottomstation9.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 320              2005      74
# 220               443      77
# 208               431      79
# 53                253     104
# 156               372     106
# 5                 119     108
# 316              2001     118
# 79                289     154
# 109               321     167
# 213               436     168

# %%
data10 = pd.read_csv('/Users/jenny/Desktop/citibike/2014-04-CitiBiketripdata.csv')

# %%
data10.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           558  2014-04-01 00:00:07  2014-04-01 00:09:25                82
# 1           882  2014-04-01 00:00:20  2014-04-01 00:15:02               349
# 2           587  2014-04-01 00:00:25  2014-04-01 00:10:12               293
# 3           355  2014-04-01 00:00:44  2014-04-01 00:06:39               539
# 4           524  2014-04-01 00:01:29  2014-04-01 00:10:13               459
#
#                start station name  start station latitude  \
# 0          St James Pl & Pearl St               40.711174
# 1         Rivington St & Ridge St               40.718502
# 2           Lafayette St & E 8 St               40.730287
# 3  Metropolitan Ave & Bedford Ave               40.715348
# 4                W 20 St & 11 Ave               40.746745
#
#    start station longitude  end station id         end station name  \
# 0               -74.000165            2008    Little West St & 1 Pl
# ...

# %%
topstation10 = data10.groupby(['start station id']).size().reset_index(name='counts')
topstation10.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 292               519    7996
# 294               521    7099
# 82                293    7056
# 271               497    6999
# 211               435    6130
# 78                285    5905
# 203               426    5364
# 264               490    5331
# 273               499    5241
# 182               402    5172

# %%
bottomstation10 = data10.groupby(['start station id']).size().reset_index(name='counts')
bottomstation10.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 108               321      23
# 318              2005      75
# 207               431     127
# 5                 119     153
# 155               372     157
# 314              2001     161
# 219               443     173
# 79                289     200
# 198               419     237
# 53                253     264

# %%
data11 = pd.read_csv('/Users/jenny/Desktop/citibike/2014-05-CitiBiketripdata.csv')

# %%
data11.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           158  2014-05-01 00:08:32  2014-05-01 00:11:10               438
# 1           427  2014-05-01 00:10:16  2014-05-01 00:17:23               537
# 2           357  2014-05-01 00:12:28  2014-05-01 00:18:25               491
# 3           168  2014-05-01 00:13:41  2014-05-01 00:16:29               224
# 4           638  2014-05-01 00:15:45  2014-05-01 00:26:23               454
#
#         start station name  start station latitude  start station longitude  \
# 0      St Marks Pl & 1 Ave               40.727791               -73.985649
# 1  Lexington Ave & E 24 St               40.740259               -73.984092
# 2     E 24 St & Park Ave S               40.740964               -73.986022
# 3    Spruce St & Nassau St               40.711464               -74.005524
# 4          E 51 St & 1 Ave               40.754557               -73.965930
#
# ...

# %%
topstation11 = data11.groupby(['start station id']).size().reset_index(name='counts')
topstation11.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 290               519    9747
# 292               521    9166
# 80                293    9070
# 269               497    8824
# 202               426    7687
# 210               435    7487
# 76                285    6976
# 219               444    6954
# 271               499    6839
# 15                151    6646

# %%
bottomstation11 = data11.groupby(['start station id']).size().reset_index(name='counts')
bottomstation11.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 212               437       4
# 317              2005      77
# 206               431     161
# 313              2001     182
# 5                 119     192
# 77                289     220
# 197               419     321
# 154               372     364
# 188               409     395
# 218               443     402

# %%
data12 = pd.read_csv('/Users/jenny/Desktop/citibike/2014-06-CitiBiketripdata.csv')

# %%
data12.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           520  2014-06-01 00:00:02  2014-06-01 00:08:42               358
# 1           520  2014-06-01 00:00:27  2014-06-01 00:09:07               335
# 2           414  2014-06-01 00:00:32  2014-06-01 00:07:26               439
# 3           310  2014-06-01 00:00:34  2014-06-01 00:05:44               463
# 4           457  2014-06-01 00:00:35  2014-06-01 00:08:12               352
#
#               start station name  start station latitude  \
# 0  Christopher St & Greenwich St               40.732916
# 1       Washington Pl & Broadway               40.729039
# 2                 E 4 St & 2 Ave               40.726281
# 3                9 Ave & W 16 St               40.742065
# 4                W 56 St & 6 Ave               40.763406
#
#    start station longitude  end station id          end station name  \
# 0               -74.007114             426     West St & Chambers St
# ...

# %%
topstation12 = data12.groupby(['start station id']).size().reset_index(name='counts')
topstation12.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 292               521   10929
# 290               519   10744
# 269               497    9693
# 80                293    9626
# 202               426    9170
# 142               358    8398
# 210               435    8242
# 76                285    7433
# 113               327    7323
# 181               402    7315

# %%
bottomstation12 = data12.groupby(['start station id']).size().reset_index(name='counts')
bottomstation12.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 317              2005     126
# 313              2001     139
# 5                 119     158
# 206               431     200
# 77                289     268
# 74                282     308
# 197               419     316
# 154               372     347
# 217               443     351
# 188               409     400

# %%
data13 = pd.read_csv('/Users/jenny/Desktop/citibike/2014-07-CitiBiketripdata.csv')

# %%
data13.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           404  2014-07-01 00:00:04  2014-07-01 00:06:48               545
# 1           850  2014-07-01 00:00:06  2014-07-01 00:14:16               238
# 2          1550  2014-07-01 00:00:21  2014-07-01 00:26:11               223
# 3           397  2014-07-01 00:00:29  2014-07-01 00:07:06               224
# 4           609  2014-07-01 00:00:37  2014-07-01 00:10:46               346
#
#         start station name  start station latitude  start station longitude  \
# 0          E 23 St & 1 Ave               40.736502               -73.978095
# 1  Bank St & Washington St               40.736197               -74.008592
# 2          W 13 St & 7 Ave               40.737815               -73.999947
# 3    Spruce St & Nassau St               40.711464               -74.005524
# 4      Bank St & Hudson St               40.736529               -74.006180
#
# ...

# %%
topstation13 = data13.groupby(['start station id']).size().reset_index(name='counts')
topstation13.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 292               521   13065
# 290               519   11541
# 80                293    9825
# 270               497    9748
# 202               426    8577
# 210               435    7855
# 181               402    7799
# 76                285    7608
# 15                151    7225
# 272               499    7186

# %%
bottomstation13 = data13.groupby(['start station id']).size().reset_index(name='counts')
bottomstation13.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 317              2005     111
# 313              2001     147
# 212               437     159
# 5                 119     176
# 297               527     203
# 307               538     241
# 77                289     243
# 206               431     244
# 218               443     283
# 197               419     311

# %%
data14 = pd.read_csv('/Users/jenny/Desktop/citibike/2014-08-CitiBiketripdata.csv')

# %%
data14.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          1142  2014-08-01 00:00:04  2014-08-01 00:19:06               470
# 1           117  2014-08-01 00:00:05  2014-08-01 00:02:02               236
# 2           546  2014-08-01 00:00:07  2014-08-01 00:09:13               224
# 3          2126  2014-08-01 00:00:11  2014-08-01 00:35:37               150
# 4           329  2014-08-01 00:00:15  2014-08-01 00:05:44               519
#
#          start station name  start station latitude  start station longitude  \
# 0           W 20 St & 8 Ave               40.743453               -74.000040
# 1       St Marks Pl & 2 Ave               40.728419               -73.987140
# 2     Spruce St & Nassau St               40.711464               -74.005524
# 3         E 2 St & Avenue C               40.720874               -73.980858
# 4  E 42 St & Vanderbilt Ave               40.752416               -73.978370
#
# ...

# %%
topstation14 = data14.groupby(['start station id']).size().reset_index(name='counts')
topstation14.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 292               521   11489
# 290               519   11072
# 80                293   10196
# 269               497    9469
# 201               426    8340
# 209               435    8005
# 112               327    7625
# 15                151    7615
# 180               402    7438
# 271               499    7407

# %%
bottomstation14 = data14.groupby(['start station id']).size().reset_index(name='counts')
bottomstation14.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 315              2005      84
# 311              2001     134
# 5                 119     204
# 205               431     266
# 77                289     270
# 217               443     286
# 196               419     325
# 169               391     333
# 153               372     391
# 210               436     395

# %%
data15 = pd.read_csv('/Users/jenny/Desktop/citibike/201409-citibike-tripdata.csv')

# %%
data15.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0          2828  9/1/2014 00:00:25  9/1/2014 00:47:33               386
# 1           368  9/1/2014 00:00:28  9/1/2014 00:06:36               387
# 2          2201  9/1/2014 00:00:40  9/1/2014 00:37:21               386
# 3           322  9/1/2014 00:00:41  9/1/2014 00:06:03               167
# 4          1693  9/1/2014 00:00:59  9/1/2014 00:29:12               223
#
#         start station name  start station latitude  start station longitude  \
# 0     Centre St & Worth St               40.714948               -74.002345
# 1  Centre St & Chambers St               40.712733               -74.004607
# 2     Centre St & Worth St               40.714948               -74.002345
# 3          E 39 St & 3 Ave               40.748901               -73.976049
# 4          W 13 St & 7 Ave               40.737815               -73.999947
#
#    end station id               end station name  end station latitude  \
# ...

# %%
topstation15 = data15.groupby(['start station id']).size().reset_index(name='counts')
topstation15.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 294               521   12441
# 292               519   10540
# 81                293   10357
# 271               497    9607
# 211               435    8556
# 203               426    8123
# 162               382    7740
# 77                285    7320
# 220               444    6990
# 114               327    6919

# %%
bottomstation15 = data15.groupby(['start station id']).size().reset_index(name='counts')
bottomstation15.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 317              2005      83
# 313              2001     121
# 5                 119     211
# 109               322     230
# 78                289     249
# 219               443     266
# 207               431     267
# 212               436     299
# 198               419     350
# 46                245     392

# %%
data16 = pd.read_csv('/Users/jenny/Desktop/citibike/201410-citibike-tripdata.csv')

# %%
data16.head()
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 0          1027  10/1/2014 00:00:27  10/1/2014 00:17:34               479
# 1           534  10/1/2014 00:00:36  10/1/2014 00:09:30               417
# 2           416  10/1/2014 00:00:42  10/1/2014 00:07:38               327
# 3           428  10/1/2014 00:00:50  10/1/2014 00:07:58               515
# 4           281  10/1/2014 00:01:08  10/1/2014 00:05:49               497
#
#          start station name  start station latitude  start station longitude  \
# 0           9 Ave & W 45 St               40.760193               -73.991255
# 1    Barclay St & Church St               40.712912               -74.010202
# 2  Vesey Pl & River Terrace               40.715338               -74.016584
# 3          W 43 St & 10 Ave               40.760094               -73.994618
# 4        E 17 St & Broadway               40.737050               -73.990093
#
# ...

# %%
topstation16 = data16.groupby(['start station id']).size().reset_index(name='counts')
topstation16.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 294               521   11792
# 292               519    9464
# 81                293    8881
# 271               497    8527
# 211               435    8070
# 77                285    7337
# 162               382    6624
# 105               318    6403
# 182               402    6254
# 15                151    6138

# %%
bottomstation16 = data16.groupby(['start station id']).size().reset_index(name='counts')
bottomstation16.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 297               524      64
# 318              2005      67
# 314              2001     158
# 78                289     175
# 207               431     182
# 5                 119     201
# 212               436     205
# 219               443     216
# 46                245     240
# 155               372     257

# %%
data17 = pd.read_csv('/Users/jenny/Desktop/citibike/201411-citibike-tripdata.csv')

# %%
data17.head()
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 0            97  11/1/2014 00:00:11  11/1/2014 00:01:48               344
# 1           604  11/1/2014 00:00:11  11/1/2014 00:10:15               477
# 2           629  11/1/2014 00:00:38  11/1/2014 00:11:07               546
# 3           939  11/1/2014 00:00:49  11/1/2014 00:16:28               284
# 4           825  11/1/2014 00:00:56  11/1/2014 00:14:41               280
#
#         start station name  start station latitude  start station longitude  \
# 0  Monroe St & Bedford Ave               40.685144               -73.953809
# 1          W 41 St & 8 Ave               40.756405               -73.990026
# 2     E 30 St & Park Ave S               40.744449               -73.983035
# 3    Greenwich Ave & 8 Ave               40.739017               -74.002638
# 4          E 10 St & 5 Ave               40.733320               -73.995101
#
# ...

# %%
topstation17 = data17.groupby(['start station id']).size().reset_index(name='counts')
topstation17.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 293               521    7726
# 81                293    5980
# 291               519    5779
# 270               497    5339
# 210               435    5295
# 105               318    4863
# 77                285    4816
# 277               504    4277
# 263               490    4102
# 161               382    4069

# %%
bottomstation17 = data17.groupby(['start station id']).size().reset_index(name='counts')
bottomstation17.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 318              2005      38
# 315              2001      70
# 218               443      87
# 78                289     123
# 211               436     123
# 5                 119     135
# 206               431     164
# 154               372     184
# 11                144     190
# 46                245     195

# %%
data18 = pd.read_csv('/Users/jenny/Desktop/citibike/201412-citibike-tripdata.csv')

# %%
data18.head()
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 0          1257  12/1/2014 00:00:28  12/1/2014 00:21:25               475
# 1           275  12/1/2014 00:00:43  12/1/2014 00:05:18               498
# 2           450  12/1/2014 00:01:22  12/1/2014 00:08:52               444
# 3          1126  12/1/2014 00:02:17  12/1/2014 00:21:03               475
# 4           331  12/1/2014 00:02:21  12/1/2014 00:07:52               519
#
#       start station name  start station latitude  start station longitude  \
# 0    E 16 St & Irving Pl               40.735243               -73.987586
# 1     Broadway & W 32 St               40.748549               -73.988084
# 2     Broadway & W 24 St               40.742354               -73.989151
# 3    E 16 St & Irving Pl               40.735243               -73.987586
# 4  Pershing Square North               40.751873               -73.977706
#
#    end station id      end station name  end station latitude  \
# ...

# %%
topstation18 = data18.groupby(['start station id']).size().reset_index(name='counts')
topstation18.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 293               521    6543
# 81                293    4501
# 105               318    4467
# 210               435    4031
# 291               519    3693
# 263               490    3639
# 77                285    3429
# 159               379    3056
# 161               382    2985
# 250               477    2889

# %%
bottomstation18 = data18.groupby(['start station id']).size().reset_index(name='counts')
bottomstation18.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 319              2005      46
# 315              2001      59
# 218               443      69
# 211               436      85
# 78                289      90
# 188               409      99
# 11                144     121
# 5                 119     128
# 157               376     134
# 154               372     138

# %%
data19 = pd.read_csv('/Users/jenny/Desktop/citibike/201501-citibike-tripdata.csv')

# %%
data19.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0          1346  1/1/2015 0:01  1/1/2015 0:24               455
# 1           363  1/1/2015 0:02  1/1/2015 0:08               434
# 2           346  1/1/2015 0:04  1/1/2015 0:10               491
# 3           182  1/1/2015 0:04  1/1/2015 0:07               384
# 4           969  1/1/2015 0:05  1/1/2015 0:21               474
#
#         start station name  start station latitude  start station longitude  \
# 0          1 Ave & E 44 St               40.750020               -73.969053
# 1          9 Ave & W 18 St               40.743174               -74.003664
# 2     E 24 St & Park Ave S               40.740964               -73.986022
# 3  Fulton St & Waverly Ave               40.683178               -73.965964
# 4          5 Ave & E 29 St               40.745168               -73.986831
#
#    end station id             end station name  end station latitude  \
# ...

# %%
topstation19 = data19.groupby(['start station id']).size().reset_index(name='counts')
topstation19.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 293               521    4157
# 81                293    3186
# 105               318    3139
# 210               435    2988
# 263               490    2637
# 270               497    2542
# 250               477    2468
# 159               379    2441
# 291               519    2354
# 77                285    2232

# %%
bottomstation19 = data19.groupby(['start station id']).size().reset_index(name='counts')
bottomstation19.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 315              2001      42
# 218               443      45
# 319              2005      45
# 211               436      51
# 154               372      66
# 78                289      74
# 188               409      80
# 177               398      82
# 11                144      82
# 30                218     102

# %%
data20 = pd.read_csv('/Users/jenny/Desktop/citibike/201502-citibike-tripdata.csv')

# %%
data20.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0           801  2/1/2015 0:00  2/1/2015 0:14               521
# 1           379  2/1/2015 0:00  2/1/2015 0:07               497
# 2          2474  2/1/2015 0:01  2/1/2015 0:42               281
# 3           818  2/1/2015 0:01  2/1/2015 0:15              2004
# 4           544  2/1/2015 0:01  2/1/2015 0:10               323
#
#                   start station name  start station latitude  \
# 0                    8 Ave & W 31 St               40.750450
# 1                 E 17 St & Broadway               40.737050
# 2  Grand Army Plaza & Central Park S               40.764397
# 3                  6 Ave & Broome St               40.724399
# 4        Lawrence St & Willoughby St               40.692362
#
#    start station longitude  end station id               end station name  \
# 0               -73.994811             423                W 54 St & 9 Ave
# ...

# %%
topstation20 = data20.groupby(['start station id']).size().reset_index(name='counts')
topstation20.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 293               521    2238
# 210               435    2143
# 81                293    2130
# 105               318    2102
# 250               477    2078
# 270               497    1908
# 263               490    1901
# 159               379    1856
# 308               537    1658
# 289               517    1624

# %%
bottomstation20 = data20.groupby(['start station id']).size().reset_index(name='counts')
bottomstation20.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 314              2001      21
# 177               398      25
# 317              2005      28
# 211               436      39
# 218               443      40
# 154               372      44
# 78                289      48
# 188               409      49
# 29                217      55
# 11                144      55

# %%
data21 = pd.read_csv('/Users/jenny/Desktop/citibike/201503-citibike-tripdata.csv')

# %%
data21.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0           669  3/1/2015 0:00  3/1/2015 0:11               164
# 1           750  3/1/2015 0:01  3/1/2015 0:14               258
# 2           663  3/1/2015 0:01  3/1/2015 0:12               497
# 3           480  3/1/2015 0:02  3/1/2015 0:10               470
# 4          1258  3/1/2015 0:02  3/1/2015 0:23               345
#
#             start station name  start station latitude  \
# 0              E 47 St & 2 Ave               40.753231
# 1  DeKalb Ave & Vanderbilt Ave               40.689407
# 2           E 17 St & Broadway               40.737050
# 3              W 20 St & 8 Ave               40.743453
# 4              W 13 St & 6 Ave               40.736494
#
#    start station longitude  end station id            end station name  \
# 0               -73.970325             477             W 41 St & 8 Ave
# 1               -73.968855             436    Hancock St & Bedford Ave
# ...

# %%
topstation21 = data21.groupby(['start station id']).size().reset_index(name='counts')
topstation21.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 263               490    5916
# 82                293    3574
# 160               379    3444
# 210               435    3419
# 106               318    3353
# 291               519    3186
# 308               537    3185
# 270               497    3021
# 250               477    2996
# 181               402    2596

# %%
bottomstation21 = data21.groupby(['start station id']).size().reset_index(name='counts')
bottomstation21.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 54                255       3
# 317              2005      39
# 314              2001      52
# 211               436      71
# 218               443      73
# 155               372      83
# 5                 119      84
# 206               431      99
# 196               418     114
# 188               409     115

# %%
data22 = pd.read_csv('/Users/jenny/Desktop/citibike/201504-citibike-tripdata.csv')

# %%
data22.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           241  4/1/2015 00:00:23  4/1/2015 00:04:25               494
# 1           578  4/1/2015 00:00:52  4/1/2015 00:10:31                82
# 2           484  4/1/2015 00:01:28  4/1/2015 00:09:33               223
# 3          1144  4/1/2015 00:01:31  4/1/2015 00:20:36               393
# 4          1023  4/1/2015 00:01:36  4/1/2015 00:18:40               212
#
#         start station name  start station latitude  start station longitude  \
# 0          W 26 St & 8 Ave               40.747348               -73.997236
# 1   St James Pl & Pearl St               40.711174               -74.000165
# 2          W 13 St & 7 Ave               40.737815               -73.999947
# 3        E 5 St & Avenue C               40.722992               -73.979955
# 4  W 16 St & The High Line               40.743349               -74.006818
#
#    end station id       end station name  end station latitude  \
# ...

# %%
topstation22 = data22.groupby(['start station id']).size().reset_index(name='counts')
topstation22.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 82                293    6945
# 293               521    6864
# 210               435    6356
# 270               497    6101
# 291               519    5801
# 202               426    5243
# 15                151    5188
# 78                284    4966
# 106               318    4964
# 181               402    4933

# %%
bottomstation22 = data22.groupby(['start station id']).size().reset_index(name='counts')
bottomstation22.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 55                255       6
# 317              2005      59
# 314              2001      86
# 5                 119     130
# 155               372     165
# 211               436     168
# 80                289     188
# 218               443     195
# 185               406     200
# 206               431     207

# %%
data23 = pd.read_csv('/Users/jenny/Desktop/citibike/201505-citibike-tripdata.csv')

# %%
data23.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           415  5/1/2015 00:00:11  5/1/2015 00:07:06               477
# 1          1523  5/1/2015 00:00:28  5/1/2015 00:25:52               293
# 2           642  5/1/2015 00:00:52  5/1/2015 00:11:35               380
# 3           367  5/1/2015 00:00:48  5/1/2015 00:06:55               537
# 4          2734  5/1/2015 00:00:51  5/1/2015 00:46:26               426
#
#         start station name  start station latitude  start station longitude  \
# 0          W 41 St & 8 Ave               40.756405               -73.990026
# 1    Lafayette St & E 8 St               40.730287               -73.990765
# 2         W 4 St & 7 Ave S               40.734011               -74.002939
# 3  Lexington Ave & E 24 St               40.740259               -73.984092
# 4    West St & Chambers St               40.717548               -74.013221
#
#    end station id          end station name  end station latitude  \
# ...

# %%
topstation23 = data23.groupby(['start station id']).size().reset_index(name='counts')
topstation23.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 292               521   12988
# 290               519   10388
# 82                293   10265
# 202               426    9588
# 270               497    9469
# 210               435    9283
# 272               499    8105
# 114               327    7628
# 7                 127    7534
# 15                151    7507

# %%
bottomstation23 = data23.groupby(['start station id']).size().reset_index(name='counts')
bottomstation23.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 54                255       6
# 132               347      42
# 317              2005      64
# 5                 119     158
# 313              2001     175
# 36                233     199
# 206               431     225
# 79                289     278
# 155               372     340
# 218               443     350

# %%
data24 = pd.read_csv('/Users/jenny/Desktop/citibike/201506-citibike-tripdata.csv')

# %%
data24.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0          1338  6/1/2015 0:00  6/1/2015 0:22               128
# 1           290  6/1/2015 0:00  6/1/2015 0:05               438
# 2           634  6/1/2015 0:01  6/1/2015 0:11               383
# 3           159  6/1/2015 0:01  6/1/2015 0:04               361
# 4          1233  6/1/2015 0:02  6/1/2015 0:22               382
#
#            start station name  start station latitude  \
# 0    MacDougal St & Prince St               40.727103
# 1         St Marks Pl & 1 Ave               40.727791
# 2  Greenwich Ave & Charles St               40.735238
# 3        Allen St & Hester St               40.716059
# 4     University Pl & E 14 St               40.734927
#
#    start station longitude  end station id         end station name  \
# 0               -74.002971            2021          W 45 St & 8 Ave
# 1               -73.985649             312  Allen St & E Houston St
# ...

# %%
topstation24 = data24.groupby(['start station id']).size().reset_index(name='counts')
topstation24.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 290               521   13347
# 288               519   11052
# 81                293    9457
# 267               497    8962
# 200               426    8796
# 208               435    8540
# 298               529    7772
# 7                 127    7306
# 77                285    7187
# 76                284    7162

# %%
bottomstation24 = data24.groupby(['start station id']).size().reset_index(name='counts')
bottomstation24.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 27                212       2
# 277               508      13
# 315              2005      89
# 5                 119     107
# 311              2001     143
# 216               443     232
# 204               431     233
# 78                289     249
# 153               372     279
# 209               436     303

# %%
data25 = pd.read_csv('/Users/jenny/Desktop/citibike/201507-citibike-tripdata.csv')

# %%
data25.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           732  7/1/2015 00:00:03  7/1/2015 00:12:16               489
# 1           322  7/1/2015 00:00:06  7/1/2015 00:05:29               304
# 2           790  7/1/2015 00:00:17  7/1/2015 00:13:28               447
# 3          1228  7/1/2015 00:00:23  7/1/2015 00:20:51               490
# 4          1383  7/1/2015 00:00:44  7/1/2015 00:23:48               327
#
#          start station name  start station latitude  start station longitude  \
# 0          10 Ave & W 28 St               40.750664               -74.001768
# 1     Broadway & Battery Pl               40.704633               -74.013617
# 2           8 Ave & W 52 St               40.763707               -73.985162
# 3           8 Ave & W 33 St               40.751551               -73.993934
# 4  Vesey Pl & River Terrace               40.715338               -74.016584
#
# ...

# %%
topstation25 = data25.groupby(['start station id']).size().reset_index(name='counts')
topstation25.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 293               521   14493
# 291               519   12359
# 202               426   11099
# 82                293   10341
# 270               497   10073
# 210               435    9181
# 272               499    8793
# 301               529    8647
# 114               327    8605
# 78                285    8118

# %%
bottomstation25 = data25.groupby(['start station id']).size().reset_index(name='counts')
bottomstation25.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 68                271      35
# 329              3180      51
# 318              2005      51
# 5                 119     177
# 314              2001     216
# 79                289     273
# 218               443     284
# 155               372     290
# 206               431     345
# 211               436     361

# %%
data26 = pd.read_csv('/Users/jenny/Desktop/citibike/201508-citibike-tripdata.csv')

# %%
data26.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0          1202  8/1/2015 00:00:04  8/1/2015 00:20:07               168
# 1           301  8/1/2015 00:00:05  8/1/2015 00:05:06               450
# 2           431  8/1/2015 00:00:06  8/1/2015 00:07:18               312
# 3           273  8/1/2015 00:00:09  8/1/2015 00:04:43               382
# 4          1256  8/1/2015 00:00:17  8/1/2015 00:21:13               352
#
#         start station name  start station latitude  start station longitude  \
# 0          W 18 St & 6 Ave               40.739713               -73.994564
# 1          W 49 St & 8 Ave               40.762272               -73.987882
# 2  Allen St & E Houston St               40.722055               -73.989111
# 3  University Pl & E 14 St               40.734927               -73.992005
# 4          W 56 St & 6 Ave               40.763406               -73.977225
#
#    end station id      end station name  end station latitude  \
# ...

# %%
topstation26 = data26.groupby(['start station id']).size().reset_index(name='counts')
topstation26.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 294               521   14498
# 292               519   12611
# 82                293   11801
# 203               426   11509
# 271               497   10939
# 273               499    9914
# 211               435    9839
# 15                151    9509
# 78                285    9050
# 168               387    8916

# %%
bottomstation26 = data26.groupby(['start station id']).size().reset_index(name='counts')
bottomstation26.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 68                271       3
# 348              3059      15
# 332              3041      16
# 407              3128      16
# 339              3049      19
# 336              3046      23
# 335              3044      27
# 334              3043      29
# 333              3042      30
# 345              3056      30

# %%
data27 = pd.read_csv('/Users/jenny/Desktop/citibike/201509-citibike-tripdata.csv')

# %%
data27.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           288  9/1/2015 00:00:00  9/1/2015 00:04:48               263
# 1           165  9/1/2015 00:00:00  9/1/2015 00:02:45               495
# 2           367  9/1/2015 00:00:01  9/1/2015 00:06:08              3119
# 3           926  9/1/2015 00:00:07  9/1/2015 00:15:34               536
# 4           658  9/1/2015 00:00:09  9/1/2015 00:11:07               347
#
#             start station name  start station latitude  \
# 0     Elizabeth St & Hester St               40.717290
# 1             W 47 St & 10 Ave               40.762699
# 2         Vernon Blvd & 50 Ave               40.742327
# 3              1 Ave & E 30 St               40.741444
# 4  Greenwich St & W Houston St               40.728846
#
#    start station longitude  end station id            end station name  \
# 0               -73.996375             307       Canal St & Rutgers St
# ...

# %%
topstation27 = data27.groupby(['start station id']).size().reset_index(name='counts')
topstation27.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 291               521   14923
# 289               519   14063
# 81                293   11291
# 201               426   10460
# 209               435   10286
# 268               497   10127
# 15                151    9120
# 77                285    9053
# 153               368    8525
# 114               327    8333

# %%
bottomstation27 = data27.groupby(['start station id']).size().reset_index(name='counts')
bottomstation27.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 452              3232       8
# 316              2005      55
# 449              3226      79
# 363              3080      84
# 361              3077      96
# 450              3230     128
# 413              3137     129
# 343              3059     133
# 445              3221     138
# 441              3179     149

# %%
data28 = pd.read_csv('/Users/jenny/Desktop/citibike/201510-citibike-tripdata.csv')

# %%
data28.head()
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 0           171  10/1/2015 00:00:02  10/1/2015 00:02:54               388
# 1           593  10/1/2015 00:00:02  10/1/2015 00:09:55               518
# 2           233  10/1/2015 00:00:11  10/1/2015 00:04:05               447
# 3           250  10/1/2015 00:00:15  10/1/2015 00:04:25               336
# 4           528  10/1/2015 00:00:17  10/1/2015 00:09:05              3107
#
#             start station name  start station latitude  \
# 0             W 26 St & 10 Ave               40.749718
# 1              E 39 St & 2 Ave               40.747804
# 2              8 Ave & W 52 St               40.763707
# 3  Sullivan St & Washington Sq               40.730477
# 4     Bedford Ave & Nassau Ave               40.723117
#
#    start station longitude  end station id                end station name  \
# 0               -74.002950             494                 W 26 St & 8 Ave
# ...

# %%
topstation28 = data28.groupby(['start station id']).size().reset_index(name='counts')
topstation28.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 285               519   11340
# 79                293   10989
# 205               435    9928
# 264               497    9121
# 75                285    8815
# 198               426    7922
# 14                151    7725
# 149               368    7667
# 295               529    7593
# 178               402    7362

# %%
bottomstation28 = data28.groupby(['start station id']).size().reset_index(name='counts')
bottomstation28.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 407              3130       3
# 462              3237      10
# 303               538      10
# 377              3099      35
# 313              2005      58
# 327              3044     136
# 342              3061     152
# 448              3179     152
# 340              3059     153
# 334              3053     163

# %%
data29 = pd.read_csv('/Users/jenny/Desktop/citibike/201511-citibike-tripdata.csv')

# %%
data29.head()
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 0          1110  11/1/2015 00:00:00  11/1/2015 00:18:31               537
# 1          1094  11/1/2015 00:00:01  11/1/2015 00:18:15               537
# 2           520  11/1/2015 00:00:05  11/1/2015 00:08:45               536
# 3           753  11/1/2015 00:00:15  11/1/2015 00:12:48               229
# 4           353  11/1/2015 00:00:22  11/1/2015 00:06:15               285
#
#         start station name  start station latitude  start station longitude  \
# 0  Lexington Ave & E 24 St               40.740259               -73.984092
# 1  Lexington Ave & E 24 St               40.740259               -73.984092
# 2          1 Ave & E 30 St               40.741444               -73.975361
# 3           Great Jones St               40.727434               -73.993790
# 4       Broadway & E 14 St               40.734546               -73.990741
#
# ...

# %%
topstation29 = data29.groupby(['start station id']).size().reset_index(name='counts')
topstation29.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 285               519   11267
# 80                293    8810
# 205               435    8268
# 264               497    7740
# 76                285    7175
# 15                151    6172
# 178               402    6168
# 149               368    6080
# 198               426    6060
# 75                284    5915

# %%
bottomstation29 = data29.groupby(['start station id']).size().reset_index(name='counts')
bottomstation29.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 170               394      20
# 312              2005      34
# 333              3053      80
# 451              3179      92
# 339              3059     104
# 407              3128     106
# 341              3061     112
# 326              3044     116
# 325              3043     121
# 466              3237     125

# %%
data30 = pd.read_csv('/Users/jenny/Desktop/citibike/201512-citibike-tripdata.csv')

# %%
data30.head()
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 0           475  12/1/2015 07:35:36  12/1/2015 07:43:32                72
# 1           684  12/1/2015 07:38:15  12/1/2015 07:49:39                72
# 2          1063  12/1/2015 07:44:49  12/1/2015 08:02:33                72
# 3          1075  12/1/2015 08:02:29  12/1/2015 08:20:24                72
# 4           293  12/1/2015 08:06:37  12/1/2015 08:11:30                72
#
#   start station name  start station latitude  start station longitude  \
# 0   W 52 St & 11 Ave               40.767272               -73.993929
# 1   W 52 St & 11 Ave               40.767272               -73.993929
# 2   W 52 St & 11 Ave               40.767272               -73.993929
# 3   W 52 St & 11 Ave               40.767272               -73.993929
# 4   W 52 St & 11 Ave               40.767272               -73.993929
#
#    end station id               end station name  end station latitude  \
# ...

# %%
topstation30 = data30.groupby(['start station id']).size().reset_index(name='counts')
topstation30.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 285               519    8843
# 80                293    7101
# 205               435    6918
# 76                285    6166
# 264               497    6105
# 178               402    5551
# 257               490    5090
# 15                151    5017
# 149               368    4757
# 75                284    4752

# %%
bottomstation30 = data30.groupby(['start station id']).size().reset_index(name='counts')
bottomstation30.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 78                290       1
# 469              3241      13
# 470              3242      15
# 312              2005      22
# 333              3053      70
# 407              3128      73
# 452              3179      83
# 341              3061      97
# 326              3044      99
# 355              3075      99

# %%
data31 = pd.read_csv('/Users/jenny/Desktop/citibike/201601-citibike-tripdata.csv')

# %%
data31.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           923  1/1/2016 00:00:41  1/1/2016 00:16:04               268
# 1           379  1/1/2016 00:00:45  1/1/2016 00:07:04               476
# 2           589  1/1/2016 00:00:48  1/1/2016 00:10:37               489
# 3           889  1/1/2016 00:01:06  1/1/2016 00:15:56               268
# 4          1480  1/1/2016 00:01:12  1/1/2016 00:25:52              2006
#
#        start station name  start station latitude  start station longitude  \
# 0   Howard St & Centre St               40.719105               -73.999733
# 1         E 31 St & 3 Ave               40.743943               -73.979661
# 2        10 Ave & W 28 St               40.750664               -74.001768
# 3   Howard St & Centre St               40.719105               -73.999733
# 4  Central Park S & 6 Ave               40.765909               -73.976342
#
#    end station id            end station name  end station latitude  \
# ...

# %%
topstation31 = data31.groupby(['start station id']).size().reset_index(name='counts')
topstation31.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 284               519    6437
# 204               435    4761
# 79                293    4533
# 263               497    4104
# 76                285    3813
# 256               490    3617
# 178               402    3552
# 243               477    3465
# 226               459    3160
# 23                168    3098

# %%
bottomstation31 = data31.groupby(['start station id']).size().reset_index(name='counts')
bottomstation31.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 80                294       2
# 311              2005      18
# 401              3123      30
# 325              3044      51
# 324              3043      61
# 332              3053      63
# 466              3237      63
# 340              3061      64
# 338              3059      68
# 354              3075      70

# %%
data32 = pd.read_csv('/Users/jenny/Desktop/citibike/201602-citibike-tripdata.csv')

# %%
data32.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           461  2/1/2016 00:00:08  2/1/2016 00:07:49               480
# 1           297  2/1/2016 00:00:56  2/1/2016 00:05:53               463
# 2           280  2/1/2016 00:01:00  2/1/2016 00:05:40              3134
# 3           662  2/1/2016 00:01:00  2/1/2016 00:12:02               537
# 4           355  2/1/2016 00:01:41  2/1/2016 00:07:36               284
#
#         start station name  start station latitude  start station longitude  \
# 0         W 53 St & 10 Ave               40.766697               -73.990617
# 1          9 Ave & W 16 St               40.742065               -74.004432
# 2          3 Ave & E 62 St               40.763126               -73.965269
# 3  Lexington Ave & E 24 St               40.740259               -73.984092
# 4    Greenwich Ave & 8 Ave               40.739017               -74.002638
#
#    end station id  end station name  end station latitude  \
# ...

# %%
topstation32 = data32.groupby(['start station id']).size().reset_index(name='counts')
topstation32.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 285               519    6937
# 205               435    5037
# 79                293    4913
# 264               497    4031
# 76                285    3810
# 257               490    3744
# 178               402    3739
# 227               459    3478
# 302               537    3449
# 244               477    3436

# %%
bottomstation32 = data32.groupby(['start station id']).size().reset_index(name='counts')
bottomstation32.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 312              2005      15
# 326              3044      42
# 345              3065      47
# 341              3061      48
# 402              3123      51
# 355              3075      55
# 333              3053      58
# 343              3063      61
# 323              3041      67
# 339              3059      67

# %%
data33 = pd.read_csv('/Users/jenny/Desktop/citibike/201603-citibike-tripdata.csv')

# %%
data33.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0          1491  3/1/2016 06:52:42  3/1/2016 07:17:33                72
# 1          1044  3/1/2016 07:05:50  3/1/2016 07:23:15                72
# 2           714  3/1/2016 07:15:05  3/1/2016 07:26:59                72
# 3           329  3/1/2016 07:26:04  3/1/2016 07:31:34                72
# 4          1871  3/1/2016 07:31:30  3/1/2016 08:02:41                72
#
#   start station name  start station latitude  start station longitude  \
# 0   W 52 St & 11 Ave               40.767272               -73.993929
# 1   W 52 St & 11 Ave               40.767272               -73.993929
# 2   W 52 St & 11 Ave               40.767272               -73.993929
# 3   W 52 St & 11 Ave               40.767272               -73.993929
# 4   W 52 St & 11 Ave               40.767272               -73.993929
#
#    end station id          end station name  end station latitude  \
# ...

# %%
topstation33 = data33.groupby(['start station id']).size().reset_index(name='counts')
topstation33.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 283               519   11634
# 79                293    7721
# 204               435    7493
# 263               497    6888
# 197               426    6006
# 76                285    5987
# 178               402    5944
# 256               490    5790
# 15                151    5627
# 226               459    5598

# %%
bottomstation33 = data33.groupby(['start station id']).size().reset_index(name='counts')
bottomstation33.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 470              3243       5
# 310              2005      52
# 328              3048      68
# 340              3061      70
# 379              3100      72
# 324              3043      89
# 325              3044      93
# 354              3075     104
# 338              3059     106
# 407              3128     113

# %%
data34 = pd.read_csv('/Users/jenny/Desktop/citibike/201604-citibike-tripdata.csv')

# %%
data34.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           496  4/1/2016 00:00:26  4/1/2016 00:08:42               254
# 1           104  4/1/2016 00:00:27  4/1/2016 00:02:12               311
# 2           128  4/1/2016 00:00:30  4/1/2016 00:02:38              3064
# 3          1197  4/1/2016 00:00:34  4/1/2016 00:20:31              3156
# 4           419  4/1/2016 00:00:46  4/1/2016 00:07:46               116
#
#        start station name  start station latitude  start station longitude  \
# 0         W 11 St & 6 Ave               40.735324               -73.998004
# 1  Norfolk St & Broome St               40.717227               -73.988021
# 2  Myrtle Ave & Lewis Ave               40.696820               -73.937569
# 3      E 72 St & York Ave               40.766638               -73.953483
# 4         W 17 St & 8 Ave               40.741776               -74.001497
#
#    end station id                 end station name  end station latitude  \
# ...

# %%
topstation34 = data34.groupby(['start station id']).size().reset_index(name='counts')
topstation34.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 281               519   11563
# 176               402    7884
# 202               435    7793
# 195               426    7787
# 261               497    7731
# 79                293    7666
# 224               459    6356
# 148               368    6303
# 75                284    6243
# 15                151    6218

# %%
bottomstation34 = data34.groupby(['start station id']).size().reset_index(name='counts')
bottomstation34.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 457              3229      20
# 308              2005      46
# 338              3061      81
# 336              3059     103
# 468              3243     115
# 471              3249     122
# 340              3063     123
# 323              3044     130
# 320              3041     132
# 322              3043     133

# %%
data35 = pd.read_csv('/Users/jenny/Desktop/citibike/201605-citibike-tripdata.csv')

# %%
data35.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           538  5/1/2016 00:00:03  5/1/2016 00:09:02               536
# 1           224  5/1/2016 00:00:04  5/1/2016 00:03:49               361
# 2           328  5/1/2016 00:00:14  5/1/2016 00:05:43               301
# 3          1196  5/1/2016 00:00:20  5/1/2016 00:20:17              3141
# 4           753  5/1/2016 00:00:26  5/1/2016 00:13:00               492
#
#      start station name  start station latitude  start station longitude  \
# 0       1 Ave & E 30 St               40.741444               -73.975361
# 1  Allen St & Hester St               40.716059               -73.991908
# 2     E 2 St & Avenue B               40.722174               -73.983688
# 3       1 Ave & E 68 St               40.765005               -73.958185
# 4       W 33 St & 7 Ave               40.750200               -73.990931
#
#    end station id         end station name  end station latitude  \
# ...

# %%
topstation35 = data35.groupby(['start station id']).size().reset_index(name='counts')
topstation35.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 279               519   12775
# 195               426   10128
# 79                293    9246
# 202               435    9220
# 259               497    9036
# 176               402    9002
# 274               514    7699
# 223               459    7651
# 76                285    7570
# 148               368    7566

# %%
bottomstation35 = data35.groupby(['start station id']).size().reset_index(name='counts')
bottomstation35.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 317              3014       9
# 471              3252      20
# 306              2005      58
# 472              3253      62
# 19                160      83
# 335              3059     107
# 337              3061     137
# 322              3044     142
# 398              3123     168
# 373              3097     177

# %%
data36 = pd.read_csv('/Users/jenny/Desktop/citibike/201606-citibike-tripdata.csv')

# %%
data36.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0          1470  6/1/2016 00:00:18  6/1/2016 00:24:48               380
# 1           229  6/1/2016 00:00:20  6/1/2016 00:04:09              3092
# 2           344  6/1/2016 00:00:21  6/1/2016 00:06:06               449
# 3          1120  6/1/2016 00:00:28  6/1/2016 00:19:09               522
# 4           229  6/1/2016 00:00:53  6/1/2016 00:04:42               335
#
#          start station name  start station latitude  start station longitude  \
# 0          W 4 St & 7 Ave S               40.734011               -74.002939
# 1         Berry St & N 8 St               40.719009               -73.958525
# 2           W 52 St & 9 Ave               40.764618               -73.987895
# 3   E 51 St & Lexington Ave               40.757148               -73.972078
# 4  Washington Pl & Broadway               40.729039               -73.994046
#
#    end station id         end station name  end station latitude  \
# ...

# %%
topstation36 = data36.groupby(['start station id']).size().reset_index(name='counts')
topstation36.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 279               519   15757
# 195               426   12328
# 176               402   11700
# 259               497   11268
# 202               435   10634
# 274               514   10177
# 78                293   10130
# 224               459    9559
# 74                284    9118
# 252               490    9065

# %%
bottomstation36 = data36.groupby(['start station id']).size().reset_index(name='counts')
bottomstation36.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 305              2005      53
# 151               375      75
# 359              3085     119
# 320              3044     146
# 472              3257     178
# 333              3059     193
# 335              3061     208
# 395              3123     226
# 447              3179     226
# 349              3075     241

# %%
data37 = pd.read_csv('/Users/jenny/Desktop/citibike/201607-citibike-tripdata.csv')

# %%
data37.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           704  7/1/2016 00:00:02  7/1/2016 00:11:47               459
# 1           492  7/1/2016 00:00:18  7/1/2016 00:08:31               293
# 2           191  7/1/2016 00:00:19  7/1/2016 00:03:31              3090
# 3           687  7/1/2016 00:00:24  7/1/2016 00:11:52               459
# 4           609  7/1/2016 00:00:31  7/1/2016 00:10:40               284
#
#       start station name  start station latitude  start station longitude  \
# 0       W 20 St & 11 Ave               40.746745               -74.007756
# 1  Lafayette St & E 8 St               40.730287               -73.990765
# 2    N 8 St & Driggs Ave               40.717746               -73.956001
# 3       W 20 St & 11 Ave               40.746745               -74.007756
# 4  Greenwich Ave & 8 Ave               40.739017               -74.002638
#
#    end station id             end station name  end station latitude  \
# ...

# %%
topstation37 = data37.groupby(['start station id']).size().reset_index(name='counts')
topstation37.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 278               519   13848
# 193               426   11197
# 273               514   10280
# 175               402   10231
# 258               497   10173
# 200               435   10119
# 74                284    9255
# 222               459    9122
# 15                151    8755
# 147               368    8744

# %%
bottomstation37 = data37.groupby(['start station id']).size().reset_index(name='counts')
bottomstation37.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 317              3036       2
# 316              3017       3
# 318              3040       4
# 250               489       4
# 472              3250       6
# 482              3266       6
# 451              3219      33
# 304              2005      64
# 469              3245      71
# 52                255     101

# %%
data38 = pd.read_csv('/Users/jenny/Desktop/citibike/201608-citibike-tripdata.csv')

# %%
data38.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           288  8/1/2016 00:01:22  8/1/2016 00:06:11               302
# 1           457  8/1/2016 00:01:43  8/1/2016 00:09:21               285
# 2           278  8/1/2016 00:02:10  8/1/2016 00:06:49               539
# 3           862  8/1/2016 00:02:13  8/1/2016 00:16:36               280
# 4           407  8/1/2016 00:02:21  8/1/2016 00:09:09               161
#
#                start station name  start station latitude  \
# 0               Avenue D & E 3 St               40.720828
# 1              Broadway & E 14 St               40.734546
# 2  Metropolitan Ave & Bedford Ave               40.715348
# 3                 E 10 St & 5 Ave               40.733320
# 4           LaGuardia Pl & W 3 St               40.729170
#
#    start station longitude  end station id     end station name  \
# 0               -73.977932             428       E 3 St & 1 Ave
# ...

# %%
topstation38 = data38.groupby(['start station id']).size().reset_index(name='counts')
topstation38.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 273               519   16385
# 190               426   12383
# 253               497   11328
# 268               514   11206
# 172               402   11051
# 197               435   10667
# 15                151   10374
# 246               490   10175
# 472              3263    9927
# 72                284    9898

# %%
bottomstation38 = data38.groupby(['start station id']).size().reset_index(name='counts')
bottomstation38.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 550              3394       1
# 541              3385       1
# 311              3040       2
# 524              3342       4
# 513              3326       4
# 465              3250       8
# 522              3340      10
# 529              3353      13
# 542              3386      14
# 511              3324      14

# %%
data39 = pd.read_csv('/Users/jenny/Desktop/citibike/201609-citibike-tripdata.csv')

# %%
data39.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           975  9/1/2016 00:00:02  9/1/2016 00:16:18               312
# 1          1220  9/1/2016 00:00:04  9/1/2016 00:20:25               316
# 2           308  9/1/2016 00:00:19  9/1/2016 00:05:27               479
# 3           250  9/1/2016 00:00:25  9/1/2016 00:04:35               297
# 4           439  9/1/2016 00:00:25  9/1/2016 00:07:45               494
#
#        start station name  start station latitude  start station longitude  \
# 0   Allen St & Stanton St               40.722055               -73.989111
# 1  Fulton St & William St               40.709560               -74.006536
# 2         9 Ave & W 45 St               40.760193               -73.991255
# 3         E 15 St & 3 Ave               40.734232               -73.986923
# 4         W 26 St & 8 Ave               40.747348               -73.997236
#
#    end station id           end station name  end station latitude  \
# ...

# %%
topstation39 = data39.groupby(['start station id']).size().reset_index(name='counts')
topstation39.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 273               519   16556
# 191               426   13039
# 472              3263   12982
# 254               497   11032
# 172               402   10762
# 198               435   10649
# 300              2006   10512
# 268               514   10277
# 74                285    9624
# 247               490    9460

# %%
bottomstation39 = data39.groupby(['start station id']).size().reset_index(name='counts')
bottomstation39.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 475              3266       1
# 613              3434       1
# 403              3138       1
# 312              3040       2
# 465              3250       3
# 523              3332       4
# 311              3036       6
# 561              3376       8
# 19                160       8
# 261               504      13

# %%
data40 = pd.read_csv('/Users/jenny/Desktop/citibike/201610-citibike-tripdata.csv')

# %%
data40.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            328  2016-10-01 00:00:07  2016-10-01 00:05:35               471
# 1            398  2016-10-01 00:00:11  2016-10-01 00:06:49              3147
# 2            430  2016-10-01 00:00:14  2016-10-01 00:07:25               345
# 3            351  2016-10-01 00:00:21  2016-10-01 00:06:12              3307
# 4           2693  2016-10-01 00:00:21  2016-10-01 00:45:15              3428
#
#         Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0  Grand St & Havemeyer St               40.712868               -73.956981
# 1          E 85 St & 3 Ave               40.778012               -73.954071
# 2          W 13 St & 6 Ave               40.736494               -73.997044
# 3   West End Ave & W 94 St               40.794165               -73.974124
# 4          8 Ave & W 16 St               40.740983               -74.001702
#
# ...

# %%
topstation40 = data40.groupby(['Start Station ID']).size().reset_index(name='counts')
topstation40.sort_values('counts', ascending=False).head(10)
# Out:
#      Start Station ID  counts
# 270               519   15936
# 466              3263   12523
# 169               402   10536
# 251               497   10426
# 195               435   10287
# 188               426   10233
# 72                285    9347
# 232               477    9304
# 296              2006    9233
# 244               490    9200

# %%
bottomstation40 = data40.groupby(['Start Station ID']).size().reset_index(name='counts')
bottomstation40.sort_values('counts', ascending=True).head(10)
# Out:
#      Start Station ID  counts
# 307              3017       1
# 308              3040       3
# 459              3250       6
# 460              3254       8
# 456              3245      27
# 439              3219      30
# 295              2005      88
# 522              3342     113
# 413              3154     117
# 568              3393     118

# %%
data41 = pd.read_csv('/Users/jenny/Desktop/citibike/201611-citibike-tripdata.csv')

# %%
data41.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            331  2016-11-01 00:00:08  2016-11-01 00:05:40               324
# 1            740  2016-11-01 00:00:08  2016-11-01 00:12:29               161
# 2            229  2016-11-01 00:00:11  2016-11-01 00:04:00              3074
# 3            155  2016-11-01 00:00:18  2016-11-01 00:02:53              3357
# 4            772  2016-11-01 00:00:23  2016-11-01 00:13:15               346
#
#             Start Station Name  Start Station Latitude  \
# 0      DeKalb Ave & Hudson Ave               40.689888
# 1        LaGuardia Pl & W 3 St               40.729170
# 2  Montrose Ave & Bushwick Ave               40.707678
# 3     W 106 St & Amsterdam Ave               40.800836
# 4          Bank St & Hudson St               40.736529
#
#    Start Station Longitude  End Station ID              End Station Name  \
# 0               -73.981013             419        Carlton Ave & Park Ave
# ...

# %%
topstation41 = data41.groupby(['Start Station ID']).size().reset_index(name='counts')
topstation41.sort_values('counts', ascending=False).head(10)
# Out:
#      Start Station ID  counts
# 270               519   13053
# 462              3263    9070
# 196               435    8073
# 251               497    7667
# 170               402    7530
# 244               490    7349
# 232               477    7115
# 72                285    7053
# 133               359    6654
# 457              3255    6555

# %%
bottomstation41 = data41.groupby(['Start Station ID']).size().reset_index(name='counts')
bottomstation41.sort_values('counts', ascending=True).head(10)
# Out:
#      Start Station ID  counts
# 307              3017       1
# 456              3250       1
# 605              3440       2
# 453              3245       4
# 354              3089       4
# 436              3219      27
# 295              2005      71
# 518              3342      86
# 565              3394      96
# 212               453      97

# %%
data42 = pd.read_csv('/Users/jenny/Desktop/citibike/201612-citibike-tripdata.csv')

# %%
data42.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            528  2016-12-01 00:00:04  2016-12-01 00:08:52               499
# 1            218  2016-12-01 00:00:28  2016-12-01 00:04:06              3418
# 2            399  2016-12-01 00:00:39  2016-12-01 00:07:19               297
# 3            254  2016-12-01 00:00:44  2016-12-01 00:04:59               405
# 4           1805  2016-12-01 00:00:54  2016-12-01 00:31:00               279
#
#               Start Station Name  Start Station Latitude  \
# 0             Broadway & W 60 St               40.769155
# 1   Plaza St West & Flatbush Ave               40.675021
# 2                E 15 St & 3 Ave               40.734232
# 3  Washington St & Gansevoort St               40.739323
# 4           Peck Slip & Front St               40.707873
#
#    Start Station Longitude  End Station ID               End Station Name  \
# 0               -73.981918             228                E 48 St & 3 Ave
# ...

# %%
topstation42 = data42.groupby(['Start Station ID']).size().reset_index(name='counts')
topstation42.sort_values('counts', ascending=False).head(10)
# Out:
#      Start Station ID  counts
# 269               519    9642
# 195               435    5990
# 250               497    5802
# 169               402    5420
# 71                285    5342
# 243               490    5282
# 231               477    4963
# 270               520    4822
# 464              3263    4644
# 459              3255    4622

# %%
bottomstation42 = data42.groupby(['Start Station ID']).size().reset_index(name='counts')
bottomstation42.sort_values('counts', ascending=True).head(10)
# Out:
#      Start Station ID  counts
# 458              3250       1
# 308              3036       2
# 450              3240       3
# 455              3245       5
# 307              3017       7
# 436              3219      16
# 449              3239      18
# 547              3371      53
# 295              2005      54
# 510              3330      62

# %%
data43 = pd.read_csv('/Users/jenny/Desktop/citibike/201701-citibike-tripdata.csv')

# %%
data43.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            680  2017-01-01 00:00:21  2017-01-01 00:11:41              3226
# 1           1282  2017-01-01 00:00:45  2017-01-01 00:22:08              3263
# 2            648  2017-01-01 00:00:57  2017-01-01 00:11:46              3143
# 3            631  2017-01-01 00:01:10  2017-01-01 00:11:42              3143
# 4            621  2017-01-01 00:01:25  2017-01-01 00:11:47              3143
#
#             Start Station Name  Start Station Latitude  \
# 0  W 82 St & Central Park West               40.782750
# 1       Cooper Square & E 7 St               40.729236
# 2              5 Ave & E 78 St               40.776829
# 3              5 Ave & E 78 St               40.776829
# 4              5 Ave & E 78 St               40.776829
#
#    Start Station Longitude  End Station ID             End Station Name  \
# 0               -73.971370            3165  Central Park West & W 72 St
# ...

# %%
topstation43 = data43.groupby(['Start Station ID']).size().reset_index(name='counts')
topstation43.sort_values('counts', ascending=False).head(10)
# Out:
#      Start Station ID  counts
# 269               519    8795
# 194               435    5454
# 250               497    5110
# 168               402    4913
# 243               490    4816
# 231               477    4480
# 71                285    4407
# 146               379    4150
# 216               459    4114
# 456              3255    3993

# %%
bottomstation43 = data43.groupby(['Start Station ID']).size().reset_index(name='counts')
bottomstation43.sort_values('counts', ascending=True).head(10)
# Out:
#      Start Station ID  counts
# 309              3040       1
# 308              3036       1
# 608              3446       2
# 307              3017       4
# 448              3240      19
# 434              3219      25
# 453              3245      35
# 507              3330      42
# 566              3394      46
# 527              3352      57

# %%
data44 = pd.read_csv('/Users/jenny/Desktop/citibike/201702-citibike-tripdata.csv')

# %%
data44.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0           1087  2017-02-01 00:00:13  2017-02-01 00:18:20               345
# 1            704  2017-02-01 00:00:31  2017-02-01 00:12:15              3295
# 2            212  2017-02-01 00:00:34  2017-02-01 00:04:06               336
# 3           1140  2017-02-01 00:00:44  2017-02-01 00:19:44               484
# 4            320  2017-02-01 00:00:42  2017-02-01 00:06:02               490
#
#             Start Station Name  Start Station Latitude  \
# 0              W 13 St & 6 Ave               40.736494
# 1     Central Park W & W 96 St               40.791270
# 2  Sullivan St & Washington Sq               40.730477
# 3              W 44 St & 5 Ave               40.755003
# 4              8 Ave & W 33 St               40.751551
#
#    Start Station Longitude  End Station ID          End Station Name  \
# 0               -73.997044             305           E 58 St & 3 Ave
# ...

# %%
topstation44 = data44.groupby(['Start Station ID']).size().reset_index(name='counts')
topstation44.sort_values('counts', ascending=False).head(10)
# Out:
#      Start Station ID  counts
# 268               519    8939
# 249               497    5802
# 192               435    5678
# 167               402    5421
# 242               490    5005
# 71                285    4617
# 214               459    4591
# 230               477    4539
# 269               520    4482
# 145               379    4414

# %%
bottomstation44 = data44.groupby(['Start Station ID']).size().reset_index(name='counts')
bottomstation44.sort_values('counts', ascending=True).head(10)
# Out:
#      Start Station ID  counts
# 306              3017       1
# 78                298       1
# 444              3237       2
# 358              3098       4
# 613              3454       6
# 452              3245       8
# 512              3337      11
# 447              3240      12
# 446              3239      14
# 433              3219      19

# %%
data45 = pd.read_csv('/Users/jenny/Desktop/citibike/201703-citibike-tripdata.csv')

# %%
data45.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0           1893  2017-03-01 00:00:32  2017-03-01 00:32:06              2009
# 1            223  2017-03-01 00:01:09  2017-03-01 00:04:53               127
# 2           1665  2017-03-01 00:01:27  2017-03-01 00:29:12               174
# 3            100  2017-03-01 00:01:29  2017-03-01 00:03:10               316
# 4           1229  2017-03-01 00:01:33  2017-03-01 00:22:02               536
#
#          Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0  Catherine St & Monroe St               40.711174               -73.996826
# 1     Barrow St & Hudson St               40.731724               -74.006744
# 2           E 25 St & 1 Ave               40.738177               -73.977387
# 3    Fulton St & William St               40.709560               -74.006536
# 4           1 Ave & E 30 St               40.741444               -73.975361
#
# ...

# %%
topstation45 = data45.groupby(['Start Station ID']).size().reset_index(name='counts')
topstation45.sort_values('counts', ascending=False).head(10)
# Out:
#      Start Station ID  counts
# 269               519    9076
# 250               497    5443
# 194               435    5305
# 245               492    5293
# 168               402    5173
# 243               490    4715
# 231               477    4518
# 146               379    4476
# 270               520    4392
# 450              3255    4334

# %%
bottomstation45 = data45.groupby(['Start Station ID']).size().reset_index(name='counts')
bottomstation45.sort_values('counts', ascending=True).head(10)
# Out:
#      Start Station ID  counts
# 78                298       1
# 306              3040       6
# 443              3239       7
# 444              3240      12
# 603              3441      21
# 562              3394      27
# 432              3219      28
# 613              3456      30
# 508              3337      34
# 505              3333      36

# %%
data46 = pd.read_csv('/Users/jenny/Desktop/citibike/201704-citibike-tripdata.csv')

# %%
data46.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           195  2017-04-01 00:00:58  2017-04-01 00:04:14               217
# 1           585  2017-04-01 00:01:54  2017-04-01 00:11:40               490
# 2           665  2017-04-01 00:01:56  2017-04-01 00:13:01               504
# 3           262  2017-04-01 00:02:24  2017-04-01 00:06:47               445
# 4           134  2017-04-01 00:02:36  2017-04-01 00:04:50              3423
#
#                 start station name  start station latitude  \
# 0                    Old Fulton St               40.702772
# 1                  8 Ave & W 33 St               40.751551
# 2                  1 Ave & E 16 St               40.732219
# 3               E 10 St & Avenue A               40.727408
# 4  West Drive & Prospect Park West               40.661063
#
#    start station longitude  end station id           end station name  \
# 0               -73.993836             430           York St & Jay St
# ...

# %%
topstation46 = data46.groupby(['start station id']).size().reset_index(name='counts')
topstation46.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 266               519   12408
# 247               497    9716
# 292              2006    9194
# 185               426    9180
# 165               402    8935
# 145               382    8804
# 192               435    8721
# 67                281    7667
# 214               459    7647
# 261               514    7453

# %%
bottomstation46 = data46.groupby(['start station id']).size().reset_index(name='counts')
bottomstation46.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 439              3239       1
# 440              3240       3
# 447              3254       7
# 427              3182       8
# 366              3114      19
# 445              3245      24
# 428              3219      41
# 557              3394      44
# 501              3333      51
# 498              3330      90

# %%
data47 = pd.read_csv('/Users/jenny/Desktop/citibike/201705-citibike-tripdata.csv')

# %%
data47.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           254  2017-05-01 00:00:13  2017-05-01 00:04:27               511
# 1           248  2017-05-01 00:00:19  2017-05-01 00:04:28               511
# 2          1120  2017-05-01 00:00:19  2017-05-01 00:19:00               242
# 3           212  2017-05-01 00:00:24  2017-05-01 00:03:56               168
# 4           686  2017-05-01 00:00:29  2017-05-01 00:11:55               494
#
#            start station name  start station latitude  \
# 0          E 14 St & Avenue B               40.729387
# 1          E 14 St & Avenue B               40.729387
# 2  Carlton Ave & Flushing Ave               40.697787
# 3             W 18 St & 6 Ave               40.739713
# 4             W 26 St & 8 Ave               40.747348
#
#    start station longitude  end station id          end station name  \
# 0               -73.977724             394         E 9 St & Avenue C
# ...

# %%
topstation47 = data47.groupby(['start station id']).size().reset_index(name='counts')
topstation47.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 270               519   15526
# 168               402   12214
# 188               426   10617
# 251               497   10537
# 195               435   10021
# 453              3255    9387
# 244               490    9353
# 69                281    9287
# 217               459    8551
# 296              2006    8255

# %%
bottomstation47 = data47.groupby(['start station id']).size().reset_index(name='counts')
bottomstation47.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 442              3239       2
# 443              3240       2
# 623              3468       3
# 306              3040       5
# 12                147       5
# 450              3250       5
# 247               493      10
# 50                255      10
# 431              3219      30
# 599              3432      33

# %%
data48 = pd.read_csv('/Users/jenny/Desktop/citibike/201706-citibike-tripdata.csv')

# %%
data48.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          1397  2017-06-01 00:00:02  2017-06-01 00:23:19               515
# 1          1103  2017-06-01 00:00:13  2017-06-01 00:18:37               488
# 2          1810  2017-06-01 00:00:20  2017-06-01 00:30:31               461
# 3          1760  2017-06-01 00:00:24  2017-06-01 00:29:45              2009
# 4          2165  2017-06-01 00:00:33  2017-06-01 00:36:38               360
#
#          start station name  start station latitude  start station longitude  \
# 0          W 43 St & 10 Ave               40.760094               -73.994618
# 1           W 39 St & 9 Ave               40.756458               -73.993722
# 2           E 20 St & 2 Ave               40.735877               -73.982050
# 3  Catherine St & Monroe St               40.711174               -73.996826
# 4      William St & Pine St               40.707179               -74.008873
#
# ...

# %%
topstation48 = data48.groupby(['start station id']).size().reset_index(name='counts')
topstation48.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 265               519   16364
# 184               426   13542
# 246               497   11703
# 164               402   11388
# 260               514   11301
# 191               435   10889
# 213               459   10574
# 447              3255   10497
# 240               490   10009
# 136               368    9142

# %%
bottomstation48 = data48.groupby(['start station id']).size().reset_index(name='counts')
bottomstation48.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 301              3040       1
# 443              3248       2
# 437              3239       4
# 300              3036       4
# 621              3470       5
# 445              3250       6
# 623              3474      28
# 619              3468      32
# 595              3432      59
# 449              3257      69

# %%
data49 = pd.read_csv('/Users/jenny/Desktop/citibike/201707-citibike-tripdata.csv')

# %%
data49.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           364  2017-07-01 00:00:00  2017-07-01 00:06:05               539
# 1          2142  2017-07-01 00:00:03  2017-07-01 00:35:46               293
# 2           328  2017-07-01 00:00:08  2017-07-01 00:05:37              3242
# 3          2530  2017-07-01 00:00:11  2017-07-01 00:42:22              2002
# 4          2534  2017-07-01 00:00:15  2017-07-01 00:42:29              2002
#
#                start station name  start station latitude  \
# 0  Metropolitan Ave & Bedford Ave               40.715348
# 1           Lafayette St & E 8 St               40.730207
# 2      Schermerhorn St & Court St               40.691029
# 3    Wythe Ave & Metropolitan Ave               40.716887
# 4    Wythe Ave & Metropolitan Ave               40.716887
#
#    start station longitude  end station id          end station name  \
# 0               -73.960241            3107  Bedford Ave & Nassau Ave
# ...

# %%
topstation49 = data49.groupby(['start station id']).size().reset_index(name='counts')
topstation49.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 264               519   14853
# 184               426   14118
# 259               514   12263
# 245               497   11124
# 213               459   10652
# 191               435   10628
# 164               402   10401
# 65                281    9934
# 289              2006    9513
# 239               490    9500

# %%
bottomstation49 = data49.groupby(['start station id']).size().reset_index(name='counts')
bottomstation49.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 299              3036       1
# 617              3470       2
# 441              3250       3
# 615              3468      31
# 439              3245      62
# 621              3477      67
# 590              3432      77
# 496              3333     191
# 288              2005     196
# 555              3395     207

# %%
data50 = pd.read_csv('/Users/jenny/Desktop/citibike/201708-citibike-tripdata.csv')

# %%
data50.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          2110  2017-08-01 00:00:00  2017-08-01 00:35:11               470
# 1           160  2017-08-01 00:00:10  2017-08-01 00:02:51               348
# 2          1644  2017-08-01 00:00:17  2017-08-01 00:27:41              3165
# 3           323  2017-08-01 00:00:27  2017-08-01 00:05:51               389
# 4           109  2017-08-01 00:00:41  2017-08-01 00:02:31              3145
#
#             start station name  start station latitude  \
# 0              W 20 St & 8 Ave               40.743453
# 1       W Broadway & Spring St               40.724910
# 2  Central Park West & W 72 St               40.775794
# 3          Broadway & Berry St               40.710446
# 4           E 84 St & Park Ave               40.778627
#
#    start station longitude  end station id              end station name  \
# 0               -74.000040            3289       W 90 St & Amsterdam Ave
# ...

# %%
topstation50 = data50.groupby(['start station id']).size().reset_index(name='counts')
topstation50.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 263               519   16397
# 184               426   14043
# 245               497   12717
# 258               514   11971
# 164               402   11257
# 191               435   11184
# 213               459   10901
# 239               490   10462
# 65                281   10402
# 441              3255   10261

# %%
bottomstation50 = data50.groupby(['start station id']).size().reset_index(name='counts')
bottomstation50.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 437              3245       1
# 439              3250       2
# 615              3470       2
# 298              3040       3
# 623              3488       5
# 622              3485      10
# 613              3468      37
# 589              3432     102
# 624              3489     110
# 553              3394     182

# %%
data51 = pd.read_csv('/Users/jenny/Desktop/citibike/201709-citibike-tripdata.csv')

# %%
data51.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           362  2017-09-01 00:00:17  2017-09-01 00:06:19              3331
# 1           188  2017-09-01 00:00:21  2017-09-01 00:03:30              3101
# 2           305  2017-09-01 00:00:25  2017-09-01 00:05:30              3140
# 3           223  2017-09-01 00:00:52  2017-09-01 00:04:36               236
# 4           758  2017-09-01 00:01:01  2017-09-01 00:13:40              3427
#
#          start station name  start station latitude  start station longitude  \
# 0   Riverside Dr & W 104 St               40.801343               -73.971146
# 1     N 12 St & Bedford Ave               40.720798               -73.954847
# 2           1 Ave & E 78 St               40.771404               -73.953517
# 3       St Marks Pl & 2 Ave               40.728419               -73.987140
# 4  Lafayette St & Jersey St               40.724305               -73.996010
#
# ...

# %%
topstation51 = data51.groupby(['start station id']).size().reset_index(name='counts')
topstation51.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 260               519   17359
# 181               426   13132
# 242               497   12391
# 188               435   11517
# 161               402   11483
# 255               514   11356
# 437              3255   11351
# 67                285   10634
# 236               490   10226
# 263               523    9901

# %%
bottomstation51 = data51.groupby(['start station id']).size().reset_index(name='counts')
bottomstation51.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 613              3485       1
# 677              3633       1
# 295              3040       1
# 434              3245       1
# 675              3610       4
# 664              3586       4
# 667              3591       6
# 394              3155       9
# 674              3609      10
# 673              3605      11

# %%
data52 = pd.read_csv('/Users/jenny/Desktop/citibike/201710-citibike-tripdata.csv')

# %%
data52.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           457  2017-10-01 00:00:00  2017-10-01 00:07:38               479
# 1          6462  2017-10-01 00:00:20  2017-10-01 01:48:03               279
# 2           761  2017-10-01 00:00:27  2017-10-01 00:13:09               504
# 3          1193  2017-10-01 00:00:29  2017-10-01 00:20:22              3236
# 4          2772  2017-10-01 00:00:32  2017-10-01 00:46:44              2006
#
#        start station name  start station latitude  start station longitude  \
# 0         9 Ave & W 45 St               40.760193               -73.991255
# 1    Peck Slip & Front St               40.707873               -74.001670
# 2         1 Ave & E 16 St               40.732219               -73.981656
# 3      W 42 St & Dyer Ave               40.758985               -73.993800
# 4  Central Park S & 6 Ave               40.765909               -73.976342
#
# ...

# %%
topstation52 = data52.groupby(['start station id']).size().reset_index(name='counts')
topstation52.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 258               519   17995
# 160               402   12641
# 187               435   12370
# 241               497   12311
# 180               426   11738
# 436              3255   11606
# 68                285   10652
# 235               490   10192
# 254               514    9893
# 209               459    9882

# %%
bottomstation52 = data52.groupby(['start station id']).size().reset_index(name='counts')
bottomstation52.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 755              3647       1
# 617              3488       1
# 294              3040       1
# 754              3646       2
# 433              3245       2
# 732              3611       5
# 15                153       6
# 418              3215       8
# 748              3636       8
# 684              3559      17

# %%
data53 = pd.read_csv('/Users/jenny/Desktop/citibike/201711-citibike-tripdata.csv')

# %%
data53.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           297  2017-11-01 00:00:01  2017-11-01 00:04:59               418
# 1           269  2017-11-01 00:00:01  2017-11-01 00:04:30              3556
# 2           285  2017-11-01 00:00:04  2017-11-01 00:04:50               275
# 3           478  2017-11-01 00:00:13  2017-11-01 00:08:11              3545
# 4           574  2017-11-01 00:00:20  2017-11-01 00:09:54               458
#
#             start station name  start station latitude  \
# 0           Front St & Gold St               40.702240
# 1               24 St & 41 Ave               40.752709
# 2  Washington Ave & Greene Ave               40.686501
# 3          Broadway & W 122 St               40.812056
# 4             11 Ave & W 27 St               40.751396
#
#    start station longitude  end station id          end station name  \
# 0               -73.982578             414   Pearl St & Anchorage Pl
# ...

# %%
topstation53 = data53.groupby(['start station id']).size().reset_index(name='counts')
topstation53.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 256               519   15203
# 238               497    9030
# 185               435    8996
# 158               402    8781
# 430              3255    8556
# 66                285    8208
# 232               490    7772
# 221               477    7143
# 259               523    6947
# 69                293    6925

# %%
bottomstation53 = data53.groupby(['start station id']).size().reset_index(name='counts')
bottomstation53.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 604              3485       2
# 739              3636       3
# 17                164       5
# 412              3182       6
# 429              3254       6
# 423              3239      13
# 124               359      15
# 601              3476      15
# 597              3468      19
# 749              3650      25

# %%
data54 = pd.read_csv('/Users/jenny/Desktop/citibike/201712-citibike-tripdata.csv')

# %%
data54.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           256  2017-12-01 00:00:00  2017-12-01 00:04:17               324
# 1           325  2017-12-01 00:00:17  2017-12-01 00:05:43               470
# 2           967  2017-12-01 00:00:19  2017-12-01 00:16:26               347
# 3           125  2017-12-01 00:00:20  2017-12-01 00:02:26              3077
# 4           451  2017-12-01 00:00:28  2017-12-01 00:08:00               368
#
#             start station name  start station latitude  \
# 0      DeKalb Ave & Hudson Ave               40.689888
# 1              W 20 St & 8 Ave               40.743453
# 2  Greenwich St & W Houston St               40.728846
# 3         Stagg St & Union Ave               40.708771
# 4           Carmine St & 6 Ave               40.730386
#
#    start station longitude  end station id        end station name  \
# 0               -73.981013             262         Washington Park
# ...

# %%
topstation54 = data54.groupby(['start station id']).size().reset_index(name='counts')
topstation54.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 254               519    9801
# 430              3255    6619
# 183               435    6370
# 236               497    6334
# 158               402    5983
# 66                285    5478
# 230               490    5423
# 219               477    4977
# 65                284    4977
# 257               523    4760

# %%
bottomstation54 = data54.groupby(['start station id']).size().reset_index(name='counts')
bottomstation54.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 658              3543       1
# 737              3631       1
# 290              3036       9
# 604              3488      10
# 424              3239      13
# 710              3596      15
# 575              3432      20
# 628              3512      21
# 751              3654      23
# 484              3333      24

# %%
data55 = pd.read_csv('/Users/jenny/Desktop/citibike/201801_citibikejc_tripdata.csv')

# %%
data55.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           132  2018-01-01 00:01:46  2018-01-01 00:03:58              3186
# 1           560  2018-01-01 01:27:17  2018-01-01 01:36:38              3276
# 2           294  2018-01-01 01:29:03  2018-01-01 01:33:58              3195
# 3           197  2018-01-01 01:59:32  2018-01-01 02:02:49              3211
# 4           932  2018-01-01 02:06:18  2018-01-01 02:21:50              3183
#
#   start station name  start station latitude  start station longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1   Marin Light Rail               40.714584               -74.042817
# 2            Sip Ave               40.730743               -74.063784
# 3         Newark Ave               40.721525               -74.046305
# 4     Exchange Place               40.716247               -74.033459
#
#    end station id       end station name  end station latitude  \
# ...

# %%
topstation55 = data55.groupby(['start station id']).size().reset_index(name='counts')
topstation55.sort_values('counts', ascending=False).head(10)
# Out:
#     start station id  counts
# 3               3186    1716
# 19              3203     843
# 12              3195     796
# 0               3183     756
# 18              3202     569
# 33              3267     508
# 25              3211     395
# 27              3213     380
# 1               3184     341
# 2               3185     335

# %%
bottomstation55 = data55.groupby(['start station id']).size().reset_index(name='counts')
bottomstation55.sort_values('counts', ascending=True).head(10)
# Out:
#     start station id  counts
# 48              3426       1
# 37              3271       1
# 40              3274       2
# 29              3216       3
# 30              3217       4
# 6               3189       7
# 16              3200       7
# 5               3188      13
# 34              3268      26
# 7               3190      26

# %%
data56 = pd.read_csv('/Users/jenny/Desktop/citibike/201801_citibikenyc_tripdata.csv')

# %%
data56.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           196  2018-01-01 00:01:51  2018-01-01 00:05:07               315
# 1           207  2018-01-01 00:02:44  2018-01-01 00:06:11              3224
# 2           613  2018-01-01 00:03:15  2018-01-01 00:13:28               386
# 3           375  2018-01-01 00:06:44  2018-01-01 00:12:59               466
# 4           402  2018-01-01 00:06:57  2018-01-01 00:13:40               438
#
#          start station name  start station latitude  start station longitude  \
# 0  South St & Gouverneur Ln               40.703554               -74.006702
# 1       W 13 St & Hudson St               40.739974               -74.005139
# 2      Centre St & Worth St               40.714948               -74.002345
# 3           W 25 St & 6 Ave               40.743954               -73.991449
# 4       St Marks Pl & 1 Ave               40.727791               -73.985649
#
# ...

# %%
topstation56 = data56.groupby(['start station id']).size().reset_index(name='counts')
topstation56.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 256               519    8080
# 185               435    5093
# 432              3255    4852
# 159               402    4526
# 238               497    4503
# 232               490    4281
# 259               523    4278
# 221               477    4256
# 66                285    4223
# 206               459    4057

# %%
bottomstation56 = data56.groupby(['start station id']).size().reset_index(name='counts')
bottomstation56.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 760              3662       1
# 607              3488       1
# 181               428       1
# 431              3250       1
# 605              3485       2
# 710              3594       5
# 577              3432      10
# 425              3239      11
# 631              3512      11
# 673              3557      23

# %%
data57 = pd.read_csv('/Users/jenny/Desktop/citibike/201802_citibikejc_tripdata.csv')

# %%
data57.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           386  2018-02-01 00:30:21  2018-02-01 00:36:47              3205
# 1           724  2018-02-01 00:59:14  2018-02-01 01:11:19              3225
# 2           452  2018-02-01 03:50:25  2018-02-01 03:57:57              3280
# 3           358  2018-02-01 05:06:52  2018-02-01 05:12:51              3279
# 4           218  2018-02-01 05:14:48  2018-02-01 05:18:26              3267
#
#       start station name  start station latitude  start station longitude  \
# 0      JC Medical Center               40.716540               -74.049638
# 1  Baldwin at Montgomery               40.723659               -74.064194
# 2            Astor Place               40.719282               -74.071262
# 3            Dixon Mills               40.721630               -74.049968
# 4           Morris Canal               40.712419               -74.038526
#
# ...

# %%
topstation57 = data57.groupby(['start station id']).size().reset_index(name='counts')
topstation57.sort_values('counts', ascending=False).head(10)
# Out:
#     start station id  counts
# 3               3186    2074
# 19              3203     957
# 0               3183     926
# 12              3195     915
# 18              3202     685
# 33              3267     607
# 25              3211     438
# 1               3184     425
# 27              3213     420
# 35              3269     411

# %%
bottomstation57 = data57.groupby(['start station id']).size().reset_index(name='counts')
bottomstation57.sort_values('counts', ascending=True).head(10)
# Out:
#     start station id  counts
# 48              3426       1
# 30              3217       4
# 40              3274       6
# 29              3216       6
# 37              3271       7
# 16              3200       7
# 6               3189       8
# 5               3188      13
# 43              3277      28
# 17              3201      37

# %%
data58 = pd.read_csv('/Users/jenny/Desktop/citibike/201802_citibikenyc_tripdata.csv')

# %%
data58.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           509  2018-02-01 00:00:04  2018-02-01 00:08:34              3458
# 1           513  2018-02-01 00:00:15  2018-02-01 00:08:49               459
# 2           516  2018-02-01 00:00:16  2018-02-01 00:08:52               459
# 3           196  2018-02-01 00:00:16  2018-02-01 00:03:32              3318
# 4           491  2018-02-01 00:00:20  2018-02-01 00:08:31               499
#
#    start station name  start station latitude  start station longitude  \
# 0     W 55 St & 6 Ave               40.763094               -73.978350
# 1    W 20 St & 11 Ave               40.746745               -74.007756
# 2    W 20 St & 11 Ave               40.746745               -74.007756
# 3     2 Ave & E 96 St               40.783964               -73.947167
# 4  Broadway & W 60 St               40.769155               -73.981918
#
#    end station id         end station name  end station latitude  \
# ...

# %%
topstation58 = data58.groupby(['start station id']).size().reset_index(name='counts')
topstation58.sort_values('counts', ascending=False).head(10)
# Out:
#      start station id  counts
# 255               519    9059
# 159               402    5729
# 184               435    5721
# 237               497    5362
# 431              3255    5268
# 231               490    5080
# 66                285    4857
# 220               477    4764
# 258               523    4596
# 125               359    4475

# %%
bottomstation58 = data58.groupby(['start station id']).size().reset_index(name='counts')
bottomstation58.sort_values('counts', ascending=True).head(10)
# Out:
#      start station id  counts
# 291              3040       1
# 605              3485       2
# 607              3487      10
# 752              3650      11
# 576              3432      16
# 485              3333      22
# 631              3512      22
# 424              3238      25
# 734              3620      29
# 599              3468      30
